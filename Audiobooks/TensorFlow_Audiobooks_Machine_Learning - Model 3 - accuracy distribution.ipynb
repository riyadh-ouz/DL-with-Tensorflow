# %% [markdown]
# # Practical example. Audiobooks

# %% [markdown]
# ## Create the machine learning algorithm, Accuracy distribution

# %% [markdown]
# ### Import the relevant libraries

# %%
import io
import itertools

import numpy as np
import sklearn.metrics

import tensorflow as tf
from tensorboard.plugins.hparams import api as hp

import matplotlib.pyplot as plt

# %% [markdown]
# ### Data

# %%
npz = np.load('Audiobooks_data_train.npz')

train_inputs = npz['inputs'].astype(np.float)
train_targets = npz['targets'].astype(np.int)

npz = np.load('Audiobooks_data_validation.npz')
validation_inputs, validation_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

npz = np.load('Audiobooks_data_test.npz')
test_inputs, test_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

# %% [markdown]
# ### Model
# Outline, optimizers, loss, early stopping and training

# %%
max_epochs = 20
batch_size = 64

input_size = 10
output_size = 2

# %%
HP_LAMBDA_REG = hp.HParam('lambda', hp.Discrete([5e-5, 1e-4]))
HP_DROPOUT = hp.HParam('dropout', hp.Discrete([0.0, 0.1, 0.2]))
HP_RUN_NUM = hp.HParam('run number', hp.Discrete([i + 1 for i in range(10)]))

with tf.summary.create_file_writer(r'Logs/Model 3/hparam_tuning/').as_default():
    hp.hparams_config(
        hparams = [HP_LAMBDA_REG, HP_DROPOUT, HP_RUN_NUM],
        metrics = [hp.Metric('accuracy', display_name = 'Accuracy')]
    )

# %%
# Wrapping our model and training in a function
def train_test_model(hparams, session_num):
    
    # Outlining the model/architecture of our CNN
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(128, 'relu',
                              kernel_regularizer=tf.keras.regularizers.l2(hparams[HP_LAMBDA_REG])),
        
        tf.keras.layers.Dropout(hparams[HP_DROPOUT]),
        
        tf.keras.layers.Dense(128, 'relu',
                              kernel_regularizer=tf.keras.regularizers.l2(hparams[HP_LAMBDA_REG])),
        
        tf.keras.layers.Dropout(hparams[HP_DROPOUT]),
        
        tf.keras.layers.Dense(output_size, activation='softmax')
    ])
    
    # Defining the loss function
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(name='sparse_categorical_crossentropy')
    
    # Compiling the model
    model.compile(optimizer='adam', loss=loss_fn, metrics=['sparse_categorical_crossentropy', 'accuracy'])
    
    # Defining the logging directory
    log_dir = r'Logs/Model 3/fit/' + 'run-{}'.format(session_num)

    
    def plot_confusion_matrix(cm, class_names):
        """
        Returns a matplotlib figure containing the plotted confusion matrix.

        Args:
          cm (array, shape = [n, n]): a confusion matrix of integer classes
          class_names (array, shape = [n]): String names of the integer classes
        """
        figure = plt.figure(figsize=(12, 12))
        plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
        plt.title("Confusion matrix")
        plt.colorbar()
        tick_marks = np.arange(len(class_names))
        plt.xticks(tick_marks, class_names, rotation=45)
        plt.yticks(tick_marks, class_names)

        # Normalize the confusion matrix.
        cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)

        # Use white text if squares are dark; otherwise black.
        threshold = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            color = "white" if cm[i, j] > threshold else "black"
            plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)

        plt.tight_layout()
        plt.ylabel('True label')
        plt.xlabel('Predicted label')
        return figure
    
    def plot_to_image(figure):
        """Converts the matplotlib plot specified by 'figure' to a PNG image and
        returns it. The supplied figure is closed and inaccessible after this call."""
        # Save the plot to a PNG in memory.
        buf = io.BytesIO()
        plt.savefig(buf, format='png')
        # Closing the figure prevents it from being displayed directly inside
        # the notebook.
        plt.close(figure)
        buf.seek(0)
        # Convert PNG buffer to TF image
        image = tf.image.decode_png(buf.getvalue(), channels=4)
        # Add the batch dimension
        image = tf.expand_dims(image, 0)
        return image
    
    
    # Defining a file writer for Confusion Matrix logging purposes
    file_writer_cm = tf.summary.create_file_writer(log_dir + '/cm')     
    
    
    def log_confusion_matrix(epoch, logs):
        # Use the model to predict the values from the validation dataset.
        test_pred_raw = model.predict(validation_inputs)
        test_pred = np.argmax(test_pred_raw, axis=1)

        # Calculate the confusion matrix.
        cm = sklearn.metrics.confusion_matrix(validation_targets, test_pred)
        # Log the confusion matrix as an image summary.
        figure = plot_confusion_matrix(cm, class_names=["won't buy", "will buy"])
        cm_image = plot_to_image(figure)

        # Log the confusion matrix as an image summary.
        with file_writer_cm.as_default():
            tf.summary.image("Confusion Matrix", cm_image, step=epoch)
    
    
    
    # Define the Tensorboard and Confusion Matrix callbacks.
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, profile_batch=0)
    cm_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end=log_confusion_matrix)

    
    # Defining early stopping to prevent overfitting
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor = 'val_sparse_categorical_crossentropy', # We should supply the unregularized the loss
        mode = 'auto',
        min_delta = 0,
        patience = 2,
        verbose = 0, 
        restore_best_weights = True
    )
    
    # Training the model
    model.fit(
        train_inputs,
        train_targets,
        epochs = max_epochs,
        batch_size = batch_size,
        callbacks = [tensorboard_callback, cm_callback, early_stopping],
        validation_data = (validation_inputs, validation_targets),
        verbose = 2
    )
    
    
    # Evaluating the model's performance on the validation set
    # Note that we have three metrics 'see sparse_categorical_crossentropy'
    _, __, accuracy = model.evaluate(validation_inputs, validation_targets)
    
    # Saving the current model for future reference
    model.save(r'saved_models\Model 3\Run-{}'.format(session_num))
    
    return accuracy

# %%
# Creating a function to log the resuls
def run(log_dir, hparams, session_num):
    
    with tf.summary.create_file_writer(log_dir).as_default():
        hp.hparams(hparams)
        accuracy = train_test_model(hparams, session_num)
        tf.summary.scalar('accuracy', accuracy, step=1)

# %%
session_num = 1

for lambda_reg in HP_LAMBDA_REG.domain.values:
    for dropout in HP_DROPOUT.domain.values:
        for run_number in HP_RUN_NUM.domain.values:
        
            hparams = {
                HP_LAMBDA_REG: lambda_reg,
                HP_DROPOUT: dropout,
                HP_RUN_NUM: run_number
            }

            run_name = "run-%d" % session_num
            print('--- Starting trial: %s' % run_name)
            print({h.name: hparams[h] for h in hparams})
            run('Logs/Model 3/hparam_tuning/' + run_name, hparams, session_num)

            session_num += 1
# Out:
# --- Starting trial: run-1
# {'lambda': 5e-05, 'dropout': 0.0, 'run number': 1}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4148 - sparse_categorical_crossentropy: 0.4075 - accuracy: 0.8483 - val_loss: 0.3017 - val_sparse_categorical_crossentropy: 0.2944 - val_accuracy: 0.8904
# Epoch 2/20
# 56/56 - 1s - loss: 0.3018 - sparse_categorical_crossentropy: 0.2945 - accuracy: 0.8896 - val_loss: 0.2696 - val_sparse_categorical_crossentropy: 0.2622 - val_accuracy: 0.9038
# Epoch 3/20
# 56/56 - 1s - loss: 0.2831 - sparse_categorical_crossentropy: 0.2757 - accuracy: 0.9008 - val_loss: 0.2686 - val_sparse_categorical_crossentropy: 0.2612 - val_accuracy: 0.9016
# Epoch 4/20
# 56/56 - 1s - loss: 0.2714 - sparse_categorical_crossentropy: 0.2641 - accuracy: 0.8980 - val_loss: 0.2542 - val_sparse_categorical_crossentropy: 0.2468 - val_accuracy: 0.9083
# Epoch 5/20
# 56/56 - 1s - loss: 0.2615 - sparse_categorical_crossentropy: 0.2541 - accuracy: 0.9022 - val_loss: 0.2626 - val_sparse_categorical_crossentropy: 0.2552 - val_accuracy: 0.9060
# Epoch 6/20
# 56/56 - 1s - loss: 0.2591 - sparse_categorical_crossentropy: 0.2517 - accuracy: 0.9044 - val_loss: 0.2508 - val_sparse_categorical_crossentropy: 0.2434 - val_accuracy: 0.9128
# Epoch 7/20
# 56/56 - 1s - loss: 0.2543 - sparse_categorical_crossentropy: 0.2470 - accuracy: 0.9067 - val_loss: 0.2459 - val_sparse_categorical_crossentropy: 0.2385 - val_accuracy: 0.9150
# Epoch 8/20
# 56/56 - 1s - loss: 0.2500 - sparse_categorical_crossentropy: 0.2426 - accuracy: 0.9098 - val_loss: 0.2558 - val_sparse_categorical_crossentropy: 0.2484 - val_accuracy: 0.9128
# Epoch 9/20
# 56/56 - 1s - loss: 0.2502 - sparse_categorical_crossentropy: 0.2428 - accuracy: 0.9086 - val_loss: 0.2405 - val_sparse_categorical_crossentropy: 0.2331 - val_accuracy: 0.9172
# Epoch 10/20
# 56/56 - 1s - loss: 0.2469 - sparse_categorical_crossentropy: 0.2395 - accuracy: 0.9089 - val_loss: 0.2408 - val_sparse_categorical_crossentropy: 0.2334 - val_accuracy: 0.9172
# Epoch 11/20
# 56/56 - 1s - loss: 0.2455 - sparse_categorical_crossentropy: 0.2381 - accuracy: 0.9125 - val_loss: 0.2497 - val_sparse_categorical_crossentropy: 0.2423 - val_accuracy: 0.9105
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2405 - sparse_categorical_crossentropy: 0.2331 - accuracy: 0.9172
# WARNING:tensorflow:From C:\Users\pc\anaconda3\envs\tf\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\pc\anaconda3\envs\tf\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-1\assets
# --- Starting trial: run-2
# {'lambda': 5e-05, 'dropout': 0.0, 'run number': 2}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4131 - sparse_categorical_crossentropy: 0.4057 - accuracy: 0.8516 - val_loss: 0.3034 - val_sparse_categorical_crossentropy: 0.2960 - val_accuracy: 0.8904
# Epoch 2/20
# 56/56 - 1s - loss: 0.3013 - sparse_categorical_crossentropy: 0.2938 - accuracy: 0.8899 - val_loss: 0.2698 - val_sparse_categorical_crossentropy: 0.2623 - val_accuracy: 0.9038
# Epoch 3/20
# 56/56 - 1s - loss: 0.2805 - sparse_categorical_crossentropy: 0.2729 - accuracy: 0.8966 - val_loss: 0.2591 - val_sparse_categorical_crossentropy: 0.2515 - val_accuracy: 0.9083
# Epoch 4/20
# 56/56 - 1s - loss: 0.2688 - sparse_categorical_crossentropy: 0.2611 - accuracy: 0.9030 - val_loss: 0.2608 - val_sparse_categorical_crossentropy: 0.2531 - val_accuracy: 0.9016
# Epoch 5/20
# 56/56 - 1s - loss: 0.2687 - sparse_categorical_crossentropy: 0.2611 - accuracy: 0.9025 - val_loss: 0.2648 - val_sparse_categorical_crossentropy: 0.2572 - val_accuracy: 0.9060
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2591 - sparse_categorical_crossentropy: 0.2515 - accuracy: 0.9083
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-2\assets
# --- Starting trial: run-3
# {'lambda': 5e-05, 'dropout': 0.0, 'run number': 3}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4089 - sparse_categorical_crossentropy: 0.4014 - accuracy: 0.8525 - val_loss: 0.3013 - val_sparse_categorical_crossentropy: 0.2938 - val_accuracy: 0.8949
# Epoch 2/20
# 56/56 - 1s - loss: 0.3106 - sparse_categorical_crossentropy: 0.3031 - accuracy: 0.8868 - val_loss: 0.2738 - val_sparse_categorical_crossentropy: 0.2662 - val_accuracy: 0.9016
# Epoch 3/20
# 56/56 - 1s - loss: 0.2823 - sparse_categorical_crossentropy: 0.2748 - accuracy: 0.8963 - val_loss: 0.2622 - val_sparse_categorical_crossentropy: 0.2546 - val_accuracy: 0.9016
# Epoch 4/20
# 56/56 - 1s - loss: 0.2728 - sparse_categorical_crossentropy: 0.2652 - accuracy: 0.9003 - val_loss: 0.2526 - val_sparse_categorical_crossentropy: 0.2449 - val_accuracy: 0.9060
# Epoch 5/20
# 56/56 - 1s - loss: 0.2707 - sparse_categorical_crossentropy: 0.2630 - accuracy: 0.9016 - val_loss: 0.2647 - val_sparse_categorical_crossentropy: 0.2570 - val_accuracy: 0.9105
# Epoch 6/20
# 56/56 - 1s - loss: 0.2581 - sparse_categorical_crossentropy: 0.2504 - accuracy: 0.9056 - val_loss: 0.2533 - val_sparse_categorical_crossentropy: 0.2457 - val_accuracy: 0.9038
# 14/14 [==============================] - ETA: 0s - loss: 0.3540 - sparse_categorical_crossentropy: 0.3463 - accuracy: 0.84 - 0s 1ms/step - loss: 0.2526 - sparse_categorical_crossentropy: 0.2449 - accuracy: 0.9060
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-3\assets
# --- Starting trial: run-4
# {'lambda': 5e-05, 'dropout': 0.0, 'run number': 4}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4031 - sparse_categorical_crossentropy: 0.3959 - accuracy: 0.8486 - val_loss: 0.3066 - val_sparse_categorical_crossentropy: 0.2993 - val_accuracy: 0.8881
# Epoch 2/20
# 56/56 - 1s - loss: 0.3072 - sparse_categorical_crossentropy: 0.3000 - accuracy: 0.8866 - val_loss: 0.2692 - val_sparse_categorical_crossentropy: 0.2620 - val_accuracy: 0.8993
# Epoch 3/20
# 56/56 - 1s - loss: 0.2827 - sparse_categorical_crossentropy: 0.2754 - accuracy: 0.8977 - val_loss: 0.2559 - val_sparse_categorical_crossentropy: 0.2486 - val_accuracy: 0.9060
# Epoch 4/20
# 56/56 - 1s - loss: 0.2703 - sparse_categorical_crossentropy: 0.2630 - accuracy: 0.9019 - val_loss: 0.2571 - val_sparse_categorical_crossentropy: 0.2498 - val_accuracy: 0.9105
# Epoch 5/20
# 56/56 - 1s - loss: 0.2660 - sparse_categorical_crossentropy: 0.2587 - accuracy: 0.9033 - val_loss: 0.2544 - val_sparse_categorical_crossentropy: 0.2471 - val_accuracy: 0.9083
# Epoch 6/20
# 56/56 - 2s - loss: 0.2590 - sparse_categorical_crossentropy: 0.2517 - accuracy: 0.9058 - val_loss: 0.2445 - val_sparse_categorical_crossentropy: 0.2372 - val_accuracy: 0.9105
# Epoch 7/20
# 56/56 - 1s - loss: 0.2554 - sparse_categorical_crossentropy: 0.2481 - accuracy: 0.9092 - val_loss: 0.2403 - val_sparse_categorical_crossentropy: 0.2329 - val_accuracy: 0.9105
# Epoch 8/20
# 56/56 - 1s - loss: 0.2541 - sparse_categorical_crossentropy: 0.2468 - accuracy: 0.9086 - val_loss: 0.2456 - val_sparse_categorical_crossentropy: 0.2382 - val_accuracy: 0.9128
# Epoch 9/20
# 56/56 - 1s - loss: 0.2487 - sparse_categorical_crossentropy: 0.2413 - accuracy: 0.9114 - val_loss: 0.2370 - val_sparse_categorical_crossentropy: 0.2297 - val_accuracy: 0.9128
# Epoch 10/20
# 56/56 - 1s - loss: 0.2510 - sparse_categorical_crossentropy: 0.2436 - accuracy: 0.9084 - val_loss: 0.2398 - val_sparse_categorical_crossentropy: 0.2325 - val_accuracy: 0.9172
# Epoch 11/20
# 56/56 - 1s - loss: 0.2464 - sparse_categorical_crossentropy: 0.2391 - accuracy: 0.9103 - val_loss: 0.2431 - val_sparse_categorical_crossentropy: 0.2357 - val_accuracy: 0.9195
#  1/14 [=>............................] - ETA: 0s - loss: 0.3078 - sparse_categorical_crossentropy: 0.3005 - accuracy: 0.8750WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0029s). Check your callbacks.
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2370 - sparse_categorical_crossentropy: 0.2297 - accuracy: 0.9128
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-4\assets
# --- Starting trial: run-5
# {'lambda': 5e-05, 'dropout': 0.0, 'run number': 5}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4112 - sparse_categorical_crossentropy: 0.4038 - accuracy: 0.8569 - val_loss: 0.2971 - val_sparse_categorical_crossentropy: 0.2897 - val_accuracy: 0.8859
# Epoch 2/20
# 56/56 - 1s - loss: 0.3003 - sparse_categorical_crossentropy: 0.2928 - accuracy: 0.8913 - val_loss: 0.2719 - val_sparse_categorical_crossentropy: 0.2644 - val_accuracy: 0.9038
# Epoch 3/20
# 56/56 - 1s - loss: 0.2791 - sparse_categorical_crossentropy: 0.2716 - accuracy: 0.8966 - val_loss: 0.2682 - val_sparse_categorical_crossentropy: 0.2607 - val_accuracy: 0.9016
# Epoch 4/20
# 56/56 - 1s - loss: 0.2735 - sparse_categorical_crossentropy: 0.2660 - accuracy: 0.9000 - val_loss: 0.2566 - val_sparse_categorical_crossentropy: 0.2491 - val_accuracy: 0.9128
# Epoch 5/20
# 56/56 - 1s - loss: 0.2696 - sparse_categorical_crossentropy: 0.2621 - accuracy: 0.9011 - val_loss: 0.2634 - val_sparse_categorical_crossentropy: 0.2559 - val_accuracy: 0.9083
# Epoch 6/20
# 56/56 - 1s - loss: 0.2617 - sparse_categorical_crossentropy: 0.2543 - accuracy: 0.9036 - val_loss: 0.2540 - val_sparse_categorical_crossentropy: 0.2466 - val_accuracy: 0.9083
# Epoch 7/20
# 56/56 - 1s - loss: 0.2561 - sparse_categorical_crossentropy: 0.2486 - accuracy: 0.9075 - val_loss: 0.2461 - val_sparse_categorical_crossentropy: 0.2387 - val_accuracy: 0.9105
# Epoch 8/20
# 56/56 - 1s - loss: 0.2525 - sparse_categorical_crossentropy: 0.2451 - accuracy: 0.9084 - val_loss: 0.2396 - val_sparse_categorical_crossentropy: 0.2321 - val_accuracy: 0.9172
# Epoch 9/20
# 56/56 - 1s - loss: 0.2469 - sparse_categorical_crossentropy: 0.2395 - accuracy: 0.9072 - val_loss: 0.2384 - val_sparse_categorical_crossentropy: 0.2309 - val_accuracy: 0.9195
# Epoch 10/20
# 56/56 - 1s - loss: 0.2469 - sparse_categorical_crossentropy: 0.2394 - accuracy: 0.9098 - val_loss: 0.2494 - val_sparse_categorical_crossentropy: 0.2420 - val_accuracy: 0.9128
# Epoch 11/20
# 56/56 - 1s - loss: 0.2550 - sparse_categorical_crossentropy: 0.2475 - accuracy: 0.9078 - val_loss: 0.2390 - val_sparse_categorical_crossentropy: 0.2315 - val_accuracy: 0.9195
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2384 - sparse_categorical_crossentropy: 0.2309 - accuracy: 0.9195
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-5\assets
# --- Starting trial: run-6
# {'lambda': 5e-05, 'dropout': 0.0, 'run number': 6}
# Epoch 1/20
# 56/56 - 2s - loss: 0.3988 - sparse_categorical_crossentropy: 0.3914 - accuracy: 0.8569 - val_loss: 0.2847 - val_sparse_categorical_crossentropy: 0.2772 - val_accuracy: 0.8993
# Epoch 2/20
# 56/56 - 1s - loss: 0.2997 - sparse_categorical_crossentropy: 0.2921 - accuracy: 0.8935 - val_loss: 0.2621 - val_sparse_categorical_crossentropy: 0.2545 - val_accuracy: 0.9038
# Epoch 3/20
# 56/56 - 1s - loss: 0.2808 - sparse_categorical_crossentropy: 0.2732 - accuracy: 0.8977 - val_loss: 0.2532 - val_sparse_categorical_crossentropy: 0.2456 - val_accuracy: 0.9060
# Epoch 4/20
# 56/56 - 1s - loss: 0.2740 - sparse_categorical_crossentropy: 0.2664 - accuracy: 0.9011 - val_loss: 0.2602 - val_sparse_categorical_crossentropy: 0.2526 - val_accuracy: 0.9060
# Epoch 5/20
# 56/56 - 1s - loss: 0.2622 - sparse_categorical_crossentropy: 0.2546 - accuracy: 0.9019 - val_loss: 0.2535 - val_sparse_categorical_crossentropy: 0.2459 - val_accuracy: 0.9060
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2532 - sparse_categorical_crossentropy: 0.2456 - accuracy: 0.9060
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-6\assets
# --- Starting trial: run-7
# {'lambda': 5e-05, 'dropout': 0.0, 'run number': 7}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4129 - sparse_categorical_crossentropy: 0.4055 - accuracy: 0.8486 - val_loss: 0.2979 - val_sparse_categorical_crossentropy: 0.2904 - val_accuracy: 0.8904
# Epoch 2/20
# 56/56 - 1s - loss: 0.3036 - sparse_categorical_crossentropy: 0.2961 - accuracy: 0.8882 - val_loss: 0.2691 - val_sparse_categorical_crossentropy: 0.2615 - val_accuracy: 0.9016
# Epoch 3/20
# 56/56 - 1s - loss: 0.2831 - sparse_categorical_crossentropy: 0.2755 - accuracy: 0.8963 - val_loss: 0.2564 - val_sparse_categorical_crossentropy: 0.2488 - val_accuracy: 0.9038
# Epoch 4/20
# 56/56 - 1s - loss: 0.2724 - sparse_categorical_crossentropy: 0.2647 - accuracy: 0.9005 - val_loss: 0.2632 - val_sparse_categorical_crossentropy: 0.2555 - val_accuracy: 0.8993
# Epoch 5/20
# 56/56 - 1s - loss: 0.2692 - sparse_categorical_crossentropy: 0.2615 - accuracy: 0.9003 - val_loss: 0.2452 - val_sparse_categorical_crossentropy: 0.2374 - val_accuracy: 0.9105
# Epoch 6/20
# 56/56 - 1s - loss: 0.2571 - sparse_categorical_crossentropy: 0.2493 - accuracy: 0.9036 - val_loss: 0.2561 - val_sparse_categorical_crossentropy: 0.2483 - val_accuracy: 0.9105
# Epoch 7/20
# 56/56 - 1s - loss: 0.2607 - sparse_categorical_crossentropy: 0.2529 - accuracy: 0.9058 - val_loss: 0.2480 - val_sparse_categorical_crossentropy: 0.2402 - val_accuracy: 0.9150
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2452 - sparse_categorical_crossentropy: 0.2374 - accuracy: 0.9105
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-7\assets
# --- Starting trial: run-8
# {'lambda': 5e-05, 'dropout': 0.0, 'run number': 8}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4017 - sparse_categorical_crossentropy: 0.3943 - accuracy: 0.8572 - val_loss: 0.3046 - val_sparse_categorical_crossentropy: 0.2973 - val_accuracy: 0.8881
# Epoch 2/20
# 56/56 - 1s - loss: 0.3070 - sparse_categorical_crossentropy: 0.2996 - accuracy: 0.8916 - val_loss: 0.2742 - val_sparse_categorical_crossentropy: 0.2668 - val_accuracy: 0.8993
# Epoch 3/20
# 56/56 - 1s - loss: 0.2906 - sparse_categorical_crossentropy: 0.2833 - accuracy: 0.8949 - val_loss: 0.2619 - val_sparse_categorical_crossentropy: 0.2545 - val_accuracy: 0.8993
# Epoch 4/20
# 56/56 - 1s - loss: 0.2717 - sparse_categorical_crossentropy: 0.2643 - accuracy: 0.9025 - val_loss: 0.2526 - val_sparse_categorical_crossentropy: 0.2452 - val_accuracy: 0.9083
# Epoch 5/20
# 56/56 - 1s - loss: 0.2689 - sparse_categorical_crossentropy: 0.2615 - accuracy: 0.9036 - val_loss: 0.2442 - val_sparse_categorical_crossentropy: 0.2368 - val_accuracy: 0.9083
# Epoch 6/20
# 56/56 - 1s - loss: 0.2554 - sparse_categorical_crossentropy: 0.2480 - accuracy: 0.9061 - val_loss: 0.2531 - val_sparse_categorical_crossentropy: 0.2456 - val_accuracy: 0.9083
# Epoch 7/20
# 56/56 - 1s - loss: 0.2553 - sparse_categorical_crossentropy: 0.2479 - accuracy: 0.9086 - val_loss: 0.2420 - val_sparse_categorical_crossentropy: 0.2346 - val_accuracy: 0.9105
# Epoch 8/20
# 56/56 - 1s - loss: 0.2535 - sparse_categorical_crossentropy: 0.2460 - accuracy: 0.9106 - val_loss: 0.2358 - val_sparse_categorical_crossentropy: 0.2283 - val_accuracy: 0.9150
# Epoch 9/20
# 56/56 - 1s - loss: 0.2538 - sparse_categorical_crossentropy: 0.2463 - accuracy: 0.9084 - val_loss: 0.2417 - val_sparse_categorical_crossentropy: 0.2343 - val_accuracy: 0.9105
# Epoch 10/20
# 56/56 - 1s - loss: 0.2461 - sparse_categorical_crossentropy: 0.2386 - accuracy: 0.9103 - val_loss: 0.2518 - val_sparse_categorical_crossentropy: 0.2443 - val_accuracy: 0.9128
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2358 - sparse_categorical_crossentropy: 0.2283 - accuracy: 0.9150
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-8\assets
# --- Starting trial: run-9
# {'lambda': 5e-05, 'dropout': 0.0, 'run number': 9}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4147 - sparse_categorical_crossentropy: 0.4074 - accuracy: 0.8553 - val_loss: 0.3033 - val_sparse_categorical_crossentropy: 0.2959 - val_accuracy: 0.8837
# Epoch 2/20
# 56/56 - 1s - loss: 0.3108 - sparse_categorical_crossentropy: 0.3034 - accuracy: 0.8866 - val_loss: 0.2801 - val_sparse_categorical_crossentropy: 0.2727 - val_accuracy: 0.8993
# Epoch 3/20
# 56/56 - 1s - loss: 0.2892 - sparse_categorical_crossentropy: 0.2818 - accuracy: 0.8975 - val_loss: 0.2618 - val_sparse_categorical_crossentropy: 0.2543 - val_accuracy: 0.9038
# Epoch 4/20
# 56/56 - 1s - loss: 0.2733 - sparse_categorical_crossentropy: 0.2658 - accuracy: 0.9014 - val_loss: 0.2640 - val_sparse_categorical_crossentropy: 0.2565 - val_accuracy: 0.9016
# Epoch 5/20
# 56/56 - 1s - loss: 0.2646 - sparse_categorical_crossentropy: 0.2571 - accuracy: 0.9036 - val_loss: 0.2636 - val_sparse_categorical_crossentropy: 0.2560 - val_accuracy: 0.9060
#  1/14 [=>............................] - ETA: 0s - loss: 0.3659 - sparse_categorical_crossentropy: 0.3584 - accuracy: 0.8438WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0156s). Check your callbacks.
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2618 - sparse_categorical_crossentropy: 0.2543 - accuracy: 0.9038
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-9\assets
# --- Starting trial: run-10
# {'lambda': 5e-05, 'dropout': 0.0, 'run number': 10}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4067 - sparse_categorical_crossentropy: 0.3992 - accuracy: 0.8558 - val_loss: 0.2975 - val_sparse_categorical_crossentropy: 0.2900 - val_accuracy: 0.8837
# Epoch 2/20
# 56/56 - 1s - loss: 0.3061 - sparse_categorical_crossentropy: 0.2986 - accuracy: 0.8888 - val_loss: 0.2702 - val_sparse_categorical_crossentropy: 0.2627 - val_accuracy: 0.9038
# Epoch 3/20
# 56/56 - 1s - loss: 0.2840 - sparse_categorical_crossentropy: 0.2765 - accuracy: 0.8977 - val_loss: 0.2661 - val_sparse_categorical_crossentropy: 0.2586 - val_accuracy: 0.9016
# Epoch 4/20
# 56/56 - 1s - loss: 0.2755 - sparse_categorical_crossentropy: 0.2680 - accuracy: 0.9008 - val_loss: 0.2671 - val_sparse_categorical_crossentropy: 0.2596 - val_accuracy: 0.8993
# Epoch 5/20
# 56/56 - 1s - loss: 0.2698 - sparse_categorical_crossentropy: 0.2622 - accuracy: 0.9025 - val_loss: 0.2568 - val_sparse_categorical_crossentropy: 0.2492 - val_accuracy: 0.9038
# Epoch 6/20
# 56/56 - 1s - loss: 0.2587 - sparse_categorical_crossentropy: 0.2511 - accuracy: 0.9056 - val_loss: 0.2473 - val_sparse_categorical_crossentropy: 0.2397 - val_accuracy: 0.9105
# Epoch 7/20
# 56/56 - 1s - loss: 0.2584 - sparse_categorical_crossentropy: 0.2508 - accuracy: 0.9036 - val_loss: 0.2516 - val_sparse_categorical_crossentropy: 0.2440 - val_accuracy: 0.9128
# Epoch 8/20
# 56/56 - 1s - loss: 0.2553 - sparse_categorical_crossentropy: 0.2477 - accuracy: 0.9064 - val_loss: 0.2455 - val_sparse_categorical_crossentropy: 0.2379 - val_accuracy: 0.9083
# Epoch 9/20
# 56/56 - 1s - loss: 0.2526 - sparse_categorical_crossentropy: 0.2450 - accuracy: 0.9092 - val_loss: 0.2437 - val_sparse_categorical_crossentropy: 0.2361 - val_accuracy: 0.9128
# Epoch 10/20
# 56/56 - 1s - loss: 0.2474 - sparse_categorical_crossentropy: 0.2398 - accuracy: 0.9111 - val_loss: 0.2369 - val_sparse_categorical_crossentropy: 0.2293 - val_accuracy: 0.9172
# Epoch 11/20
# 56/56 - 1s - loss: 0.2464 - sparse_categorical_crossentropy: 0.2388 - accuracy: 0.9089 - val_loss: 0.2525 - val_sparse_categorical_crossentropy: 0.2449 - val_accuracy: 0.9105
# Epoch 12/20
# 56/56 - 1s - loss: 0.2440 - sparse_categorical_crossentropy: 0.2364 - accuracy: 0.9131 - val_loss: 0.2452 - val_sparse_categorical_crossentropy: 0.2376 - val_accuracy: 0.9172
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2369 - sparse_categorical_crossentropy: 0.2293 - accuracy: 0.9172
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-10\assets
# --- Starting trial: run-11
# {'lambda': 5e-05, 'dropout': 0.1, 'run number': 1}
# Epoch 1/20
# 56/56 - 1s - loss: 0.4359 - sparse_categorical_crossentropy: 0.4286 - accuracy: 0.8340 - val_loss: 0.3085 - val_sparse_categorical_crossentropy: 0.3011 - val_accuracy: 0.8881
# Epoch 2/20
# 56/56 - 1s - loss: 0.3134 - sparse_categorical_crossentropy: 0.3060 - accuracy: 0.8860 - val_loss: 0.2848 - val_sparse_categorical_crossentropy: 0.2773 - val_accuracy: 0.8971
# Epoch 3/20
# 56/56 - 1s - loss: 0.2960 - sparse_categorical_crossentropy: 0.2886 - accuracy: 0.8933 - val_loss: 0.2605 - val_sparse_categorical_crossentropy: 0.2531 - val_accuracy: 0.9016
# Epoch 4/20
# 56/56 - 1s - loss: 0.2847 - sparse_categorical_crossentropy: 0.2772 - accuracy: 0.8972 - val_loss: 0.2622 - val_sparse_categorical_crossentropy: 0.2548 - val_accuracy: 0.9060
# Epoch 5/20
# 56/56 - 1s - loss: 0.2792 - sparse_categorical_crossentropy: 0.2717 - accuracy: 0.9005 - val_loss: 0.2507 - val_sparse_categorical_crossentropy: 0.2433 - val_accuracy: 0.9060
# Epoch 6/20
# 56/56 - 1s - loss: 0.2746 - sparse_categorical_crossentropy: 0.2672 - accuracy: 0.8989 - val_loss: 0.2625 - val_sparse_categorical_crossentropy: 0.2550 - val_accuracy: 0.9038
# Epoch 7/20
# 56/56 - 1s - loss: 0.2699 - sparse_categorical_crossentropy: 0.2625 - accuracy: 0.9000 - val_loss: 0.2491 - val_sparse_categorical_crossentropy: 0.2417 - val_accuracy: 0.9128
# Epoch 8/20
# 56/56 - 1s - loss: 0.2647 - sparse_categorical_crossentropy: 0.2573 - accuracy: 0.9033 - val_loss: 0.2455 - val_sparse_categorical_crossentropy: 0.2381 - val_accuracy: 0.9105
# Epoch 9/20
# 56/56 - 1s - loss: 0.2608 - sparse_categorical_crossentropy: 0.2534 - accuracy: 0.9061 - val_loss: 0.2458 - val_sparse_categorical_crossentropy: 0.2384 - val_accuracy: 0.9083
# Epoch 10/20
# 56/56 - 1s - loss: 0.2622 - sparse_categorical_crossentropy: 0.2548 - accuracy: 0.9030 - val_loss: 0.2507 - val_sparse_categorical_crossentropy: 0.2433 - val_accuracy: 0.9105
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2455 - sparse_categorical_crossentropy: 0.2381 - accuracy: 0.9105
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-11\assets
# --- Starting trial: run-12
# {'lambda': 5e-05, 'dropout': 0.1, 'run number': 2}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4105 - sparse_categorical_crossentropy: 0.4031 - accuracy: 0.8595 - val_loss: 0.3087 - val_sparse_categorical_crossentropy: 0.3012 - val_accuracy: 0.8904
# Epoch 2/20
# 56/56 - 1s - loss: 0.3153 - sparse_categorical_crossentropy: 0.3079 - accuracy: 0.8874 - val_loss: 0.2717 - val_sparse_categorical_crossentropy: 0.2642 - val_accuracy: 0.8993
# Epoch 3/20
# 56/56 - 1s - loss: 0.2903 - sparse_categorical_crossentropy: 0.2827 - accuracy: 0.8947 - val_loss: 0.2712 - val_sparse_categorical_crossentropy: 0.2637 - val_accuracy: 0.9016
# Epoch 4/20
# 56/56 - 1s - loss: 0.2875 - sparse_categorical_crossentropy: 0.2800 - accuracy: 0.8947 - val_loss: 0.2565 - val_sparse_categorical_crossentropy: 0.2489 - val_accuracy: 0.9060
# Epoch 5/20
# 56/56 - 1s - loss: 0.2770 - sparse_categorical_crossentropy: 0.2695 - accuracy: 0.8989 - val_loss: 0.2444 - val_sparse_categorical_crossentropy: 0.2369 - val_accuracy: 0.9105
# Epoch 6/20
# 56/56 - 2s - loss: 0.2735 - sparse_categorical_crossentropy: 0.2660 - accuracy: 0.9016 - val_loss: 0.2500 - val_sparse_categorical_crossentropy: 0.2425 - val_accuracy: 0.9105
# Epoch 7/20
# 56/56 - 1s - loss: 0.2672 - sparse_categorical_crossentropy: 0.2597 - accuracy: 0.9044 - val_loss: 0.2480 - val_sparse_categorical_crossentropy: 0.2405 - val_accuracy: 0.9083
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2444 - sparse_categorical_crossentropy: 0.2369 - accuracy: 0.9105
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-12\assets
# --- Starting trial: run-13
# {'lambda': 5e-05, 'dropout': 0.1, 'run number': 3}
# Epoch 1/20
# WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0002s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 56/56 - 2s - loss: 0.4114 - sparse_categorical_crossentropy: 0.4039 - accuracy: 0.8530 - val_loss: 0.2920 - val_sparse_categorical_crossentropy: 0.2844 - val_accuracy: 0.8993
# Epoch 2/20
# 56/56 - 1s - loss: 0.3060 - sparse_categorical_crossentropy: 0.2984 - accuracy: 0.8899 - val_loss: 0.2656 - val_sparse_categorical_crossentropy: 0.2581 - val_accuracy: 0.9016
# Epoch 3/20
# 56/56 - 1s - loss: 0.2908 - sparse_categorical_crossentropy: 0.2833 - accuracy: 0.8935 - val_loss: 0.2633 - val_sparse_categorical_crossentropy: 0.2558 - val_accuracy: 0.9060
# Epoch 4/20
# 56/56 - 1s - loss: 0.2818 - sparse_categorical_crossentropy: 0.2743 - accuracy: 0.8969 - val_loss: 0.2653 - val_sparse_categorical_crossentropy: 0.2578 - val_accuracy: 0.9083
# Epoch 5/20
# 56/56 - 1s - loss: 0.2801 - sparse_categorical_crossentropy: 0.2726 - accuracy: 0.8989 - val_loss: 0.2524 - val_sparse_categorical_crossentropy: 0.2449 - val_accuracy: 0.9083
# Epoch 6/20
# 56/56 - 1s - loss: 0.2701 - sparse_categorical_crossentropy: 0.2626 - accuracy: 0.9014 - val_loss: 0.2539 - val_sparse_categorical_crossentropy: 0.2464 - val_accuracy: 0.9060
# Epoch 7/20
# 56/56 - 1s - loss: 0.2710 - sparse_categorical_crossentropy: 0.2636 - accuracy: 0.9033 - val_loss: 0.2495 - val_sparse_categorical_crossentropy: 0.2421 - val_accuracy: 0.9038
# Epoch 8/20
# 56/56 - 1s - loss: 0.2638 - sparse_categorical_crossentropy: 0.2563 - accuracy: 0.9039 - val_loss: 0.2441 - val_sparse_categorical_crossentropy: 0.2367 - val_accuracy: 0.9150
# Epoch 9/20
# 56/56 - 1s - loss: 0.2601 - sparse_categorical_crossentropy: 0.2527 - accuracy: 0.9047 - val_loss: 0.2440 - val_sparse_categorical_crossentropy: 0.2366 - val_accuracy: 0.9083
# Epoch 10/20
# 56/56 - 1s - loss: 0.2548 - sparse_categorical_crossentropy: 0.2474 - accuracy: 0.9039 - val_loss: 0.2416 - val_sparse_categorical_crossentropy: 0.2342 - val_accuracy: 0.9128
# Epoch 11/20
# 56/56 - 1s - loss: 0.2590 - sparse_categorical_crossentropy: 0.2516 - accuracy: 0.9044 - val_loss: 0.2451 - val_sparse_categorical_crossentropy: 0.2377 - val_accuracy: 0.9128
# Epoch 12/20
# 56/56 - 1s - loss: 0.2545 - sparse_categorical_crossentropy: 0.2471 - accuracy: 0.9053 - val_loss: 0.2418 - val_sparse_categorical_crossentropy: 0.2344 - val_accuracy: 0.9150
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2416 - sparse_categorical_crossentropy: 0.2342 - accuracy: 0.9128
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-13\assets
# --- Starting trial: run-14
# {'lambda': 5e-05, 'dropout': 0.1, 'run number': 4}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4101 - sparse_categorical_crossentropy: 0.4027 - accuracy: 0.8528 - val_loss: 0.3157 - val_sparse_categorical_crossentropy: 0.3082 - val_accuracy: 0.8837
# Epoch 2/20
# 56/56 - 1s - loss: 0.3115 - sparse_categorical_crossentropy: 0.3040 - accuracy: 0.8854 - val_loss: 0.2746 - val_sparse_categorical_crossentropy: 0.2671 - val_accuracy: 0.8993
# Epoch 3/20
# 56/56 - 1s - loss: 0.2935 - sparse_categorical_crossentropy: 0.2861 - accuracy: 0.8944 - val_loss: 0.2612 - val_sparse_categorical_crossentropy: 0.2537 - val_accuracy: 0.8993
# Epoch 4/20
# 56/56 - 1s - loss: 0.2832 - sparse_categorical_crossentropy: 0.2757 - accuracy: 0.8955 - val_loss: 0.2557 - val_sparse_categorical_crossentropy: 0.2481 - val_accuracy: 0.9038
# Epoch 5/20
# 56/56 - 1s - loss: 0.2708 - sparse_categorical_crossentropy: 0.2633 - accuracy: 0.9000 - val_loss: 0.2593 - val_sparse_categorical_crossentropy: 0.2518 - val_accuracy: 0.9060
# Epoch 6/20
# 56/56 - 1s - loss: 0.2692 - sparse_categorical_crossentropy: 0.2617 - accuracy: 0.9039 - val_loss: 0.2527 - val_sparse_categorical_crossentropy: 0.2452 - val_accuracy: 0.9083
# Epoch 7/20
# 56/56 - 1s - loss: 0.2649 - sparse_categorical_crossentropy: 0.2573 - accuracy: 0.9039 - val_loss: 0.2475 - val_sparse_categorical_crossentropy: 0.2400 - val_accuracy: 0.9083
# Epoch 8/20
# 56/56 - 1s - loss: 0.2696 - sparse_categorical_crossentropy: 0.2621 - accuracy: 0.9033 - val_loss: 0.2548 - val_sparse_categorical_crossentropy: 0.2473 - val_accuracy: 0.9083
# Epoch 9/20
# 56/56 - 1s - loss: 0.2629 - sparse_categorical_crossentropy: 0.2554 - accuracy: 0.9030 - val_loss: 0.2472 - val_sparse_categorical_crossentropy: 0.2397 - val_accuracy: 0.9105
# Epoch 10/20
# 56/56 - 1s - loss: 0.2572 - sparse_categorical_crossentropy: 0.2497 - accuracy: 0.9064 - val_loss: 0.2403 - val_sparse_categorical_crossentropy: 0.2328 - val_accuracy: 0.9150
# Epoch 11/20
# 56/56 - 1s - loss: 0.2538 - sparse_categorical_crossentropy: 0.2463 - accuracy: 0.9081 - val_loss: 0.2405 - val_sparse_categorical_crossentropy: 0.2331 - val_accuracy: 0.9172
# Epoch 12/20
# 56/56 - 1s - loss: 0.2545 - sparse_categorical_crossentropy: 0.2470 - accuracy: 0.9064 - val_loss: 0.2447 - val_sparse_categorical_crossentropy: 0.2372 - val_accuracy: 0.9150
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2403 - sparse_categorical_crossentropy: 0.2328 - accuracy: 0.9150
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-14\assets
# --- Starting trial: run-15
# {'lambda': 5e-05, 'dropout': 0.1, 'run number': 5}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4292 - sparse_categorical_crossentropy: 0.4218 - accuracy: 0.8449 - val_loss: 0.3135 - val_sparse_categorical_crossentropy: 0.3060 - val_accuracy: 0.8881
# Epoch 2/20
# 56/56 - 1s - loss: 0.3142 - sparse_categorical_crossentropy: 0.3067 - accuracy: 0.8838 - val_loss: 0.2784 - val_sparse_categorical_crossentropy: 0.2708 - val_accuracy: 0.8949
# Epoch 3/20
# 56/56 - 1s - loss: 0.2931 - sparse_categorical_crossentropy: 0.2855 - accuracy: 0.8938 - val_loss: 0.2658 - val_sparse_categorical_crossentropy: 0.2582 - val_accuracy: 0.8971
# Epoch 4/20
# 56/56 - 1s - loss: 0.2898 - sparse_categorical_crossentropy: 0.2822 - accuracy: 0.8916 - val_loss: 0.2599 - val_sparse_categorical_crossentropy: 0.2523 - val_accuracy: 0.9016
# Epoch 5/20
# 56/56 - 1s - loss: 0.2801 - sparse_categorical_crossentropy: 0.2725 - accuracy: 0.8986 - val_loss: 0.2530 - val_sparse_categorical_crossentropy: 0.2454 - val_accuracy: 0.9105
# Epoch 6/20
# 56/56 - 1s - loss: 0.2774 - sparse_categorical_crossentropy: 0.2698 - accuracy: 0.8997 - val_loss: 0.2560 - val_sparse_categorical_crossentropy: 0.2484 - val_accuracy: 0.9105
# Epoch 7/20
# 56/56 - 1s - loss: 0.2711 - sparse_categorical_crossentropy: 0.2635 - accuracy: 0.9003 - val_loss: 0.2601 - val_sparse_categorical_crossentropy: 0.2525 - val_accuracy: 0.9038
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2530 - sparse_categorical_crossentropy: 0.2454 - accuracy: 0.9105
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-15\assets
# --- Starting trial: run-16
# {'lambda': 5e-05, 'dropout': 0.1, 'run number': 6}
# Epoch 1/20
# 56/56 - 2s - loss: 0.3966 - sparse_categorical_crossentropy: 0.3893 - accuracy: 0.8564 - val_loss: 0.2881 - val_sparse_categorical_crossentropy: 0.2807 - val_accuracy: 0.8904
# Epoch 2/20
# 56/56 - 1s - loss: 0.3068 - sparse_categorical_crossentropy: 0.2994 - accuracy: 0.8899 - val_loss: 0.2645 - val_sparse_categorical_crossentropy: 0.2571 - val_accuracy: 0.9038
# Epoch 3/20
# 56/56 - 1s - loss: 0.2988 - sparse_categorical_crossentropy: 0.2914 - accuracy: 0.8916 - val_loss: 0.2595 - val_sparse_categorical_crossentropy: 0.2521 - val_accuracy: 0.9060
# Epoch 4/20
# 56/56 - 1s - loss: 0.2851 - sparse_categorical_crossentropy: 0.2777 - accuracy: 0.8944 - val_loss: 0.2590 - val_sparse_categorical_crossentropy: 0.2516 - val_accuracy: 0.9105
# Epoch 5/20
# 56/56 - 1s - loss: 0.2768 - sparse_categorical_crossentropy: 0.2694 - accuracy: 0.8991 - val_loss: 0.2594 - val_sparse_categorical_crossentropy: 0.2520 - val_accuracy: 0.9016
# Epoch 6/20
# 56/56 - 1s - loss: 0.2726 - sparse_categorical_crossentropy: 0.2652 - accuracy: 0.9011 - val_loss: 0.2446 - val_sparse_categorical_crossentropy: 0.2372 - val_accuracy: 0.9105
# Epoch 7/20
# 56/56 - 1s - loss: 0.2734 - sparse_categorical_crossentropy: 0.2660 - accuracy: 0.8997 - val_loss: 0.2517 - val_sparse_categorical_crossentropy: 0.2443 - val_accuracy: 0.9128
# Epoch 8/20
# 56/56 - 1s - loss: 0.2640 - sparse_categorical_crossentropy: 0.2566 - accuracy: 0.9022 - val_loss: 0.2471 - val_sparse_categorical_crossentropy: 0.2397 - val_accuracy: 0.9105
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2446 - sparse_categorical_crossentropy: 0.2372 - accuracy: 0.9105
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-16\assets
# --- Starting trial: run-17
# {'lambda': 5e-05, 'dropout': 0.1, 'run number': 7}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4278 - sparse_categorical_crossentropy: 0.4203 - accuracy: 0.8374 - val_loss: 0.3045 - val_sparse_categorical_crossentropy: 0.2969 - val_accuracy: 0.8859
# Epoch 2/20
# 56/56 - 1s - loss: 0.3103 - sparse_categorical_crossentropy: 0.3027 - accuracy: 0.8891 - val_loss: 0.2815 - val_sparse_categorical_crossentropy: 0.2739 - val_accuracy: 0.8949
# Epoch 3/20
# 56/56 - 2s - loss: 0.2953 - sparse_categorical_crossentropy: 0.2876 - accuracy: 0.8908 - val_loss: 0.2643 - val_sparse_categorical_crossentropy: 0.2567 - val_accuracy: 0.9060
# Epoch 4/20
# 56/56 - 1s - loss: 0.2848 - sparse_categorical_crossentropy: 0.2772 - accuracy: 0.8966 - val_loss: 0.2493 - val_sparse_categorical_crossentropy: 0.2417 - val_accuracy: 0.9105
# Epoch 5/20
# 56/56 - 1s - loss: 0.2763 - sparse_categorical_crossentropy: 0.2687 - accuracy: 0.8991 - val_loss: 0.2751 - val_sparse_categorical_crossentropy: 0.2674 - val_accuracy: 0.9038
# Epoch 6/20
# 56/56 - 1s - loss: 0.2715 - sparse_categorical_crossentropy: 0.2638 - accuracy: 0.8997 - val_loss: 0.2584 - val_sparse_categorical_crossentropy: 0.2508 - val_accuracy: 0.9083
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2493 - sparse_categorical_crossentropy: 0.2417 - accuracy: 0.9105
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-17\assets
# --- Starting trial: run-18
# {'lambda': 5e-05, 'dropout': 0.1, 'run number': 8}
# Epoch 1/20
# 56/56 - 1s - loss: 0.4161 - sparse_categorical_crossentropy: 0.4087 - accuracy: 0.8491 - val_loss: 0.3083 - val_sparse_categorical_crossentropy: 0.3008 - val_accuracy: 0.8837
# Epoch 2/20
# 56/56 - 1s - loss: 0.3201 - sparse_categorical_crossentropy: 0.3127 - accuracy: 0.8857 - val_loss: 0.2767 - val_sparse_categorical_crossentropy: 0.2693 - val_accuracy: 0.8949
# Epoch 3/20
# 56/56 - 1s - loss: 0.3019 - sparse_categorical_crossentropy: 0.2945 - accuracy: 0.8919 - val_loss: 0.2718 - val_sparse_categorical_crossentropy: 0.2644 - val_accuracy: 0.8971
# Epoch 4/20
# 56/56 - 1s - loss: 0.2923 - sparse_categorical_crossentropy: 0.2848 - accuracy: 0.8952 - val_loss: 0.2663 - val_sparse_categorical_crossentropy: 0.2589 - val_accuracy: 0.9038
# Epoch 5/20
# 56/56 - 1s - loss: 0.2846 - sparse_categorical_crossentropy: 0.2772 - accuracy: 0.8927 - val_loss: 0.2550 - val_sparse_categorical_crossentropy: 0.2476 - val_accuracy: 0.9038
# Epoch 6/20
# 56/56 - 1s - loss: 0.2790 - sparse_categorical_crossentropy: 0.2717 - accuracy: 0.8986 - val_loss: 0.2717 - val_sparse_categorical_crossentropy: 0.2643 - val_accuracy: 0.9038
# Epoch 7/20
# 56/56 - 1s - loss: 0.2751 - sparse_categorical_crossentropy: 0.2677 - accuracy: 0.8994 - val_loss: 0.2481 - val_sparse_categorical_crossentropy: 0.2407 - val_accuracy: 0.9083
# Epoch 8/20
# 56/56 - 1s - loss: 0.2691 - sparse_categorical_crossentropy: 0.2618 - accuracy: 0.9005 - val_loss: 0.2507 - val_sparse_categorical_crossentropy: 0.2434 - val_accuracy: 0.9038
# Epoch 9/20
# 56/56 - 1s - loss: 0.2657 - sparse_categorical_crossentropy: 0.2584 - accuracy: 0.9008 - val_loss: 0.2531 - val_sparse_categorical_crossentropy: 0.2458 - val_accuracy: 0.9060
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2481 - sparse_categorical_crossentropy: 0.2407 - accuracy: 0.9083
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-18\assets
# --- Starting trial: run-19
# {'lambda': 5e-05, 'dropout': 0.1, 'run number': 9}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4259 - sparse_categorical_crossentropy: 0.4184 - accuracy: 0.8421 - val_loss: 0.3208 - val_sparse_categorical_crossentropy: 0.3132 - val_accuracy: 0.8814
# Epoch 2/20
# 56/56 - 1s - loss: 0.3200 - sparse_categorical_crossentropy: 0.3124 - accuracy: 0.8854 - val_loss: 0.2752 - val_sparse_categorical_crossentropy: 0.2676 - val_accuracy: 0.8993
# Epoch 3/20
# 56/56 - 2s - loss: 0.2963 - sparse_categorical_crossentropy: 0.2887 - accuracy: 0.8930 - val_loss: 0.2647 - val_sparse_categorical_crossentropy: 0.2571 - val_accuracy: 0.8949
# Epoch 4/20
# 56/56 - 1s - loss: 0.2848 - sparse_categorical_crossentropy: 0.2772 - accuracy: 0.8941 - val_loss: 0.2600 - val_sparse_categorical_crossentropy: 0.2524 - val_accuracy: 0.9060
# Epoch 5/20
# 56/56 - 1s - loss: 0.2768 - sparse_categorical_crossentropy: 0.2692 - accuracy: 0.8994 - val_loss: 0.2602 - val_sparse_categorical_crossentropy: 0.2526 - val_accuracy: 0.9016
# Epoch 6/20
# 56/56 - 1s - loss: 0.2765 - sparse_categorical_crossentropy: 0.2689 - accuracy: 0.9003 - val_loss: 0.2646 - val_sparse_categorical_crossentropy: 0.2570 - val_accuracy: 0.8971
#  1/14 [=>............................] - ETA: 0s - loss: 0.3701 - sparse_categorical_crossentropy: 0.3624 - accuracy: 0.8438WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0052s). Check your callbacks.
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2600 - sparse_categorical_crossentropy: 0.2524 - accuracy: 0.9060
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-19\assets
# --- Starting trial: run-20
# {'lambda': 5e-05, 'dropout': 0.1, 'run number': 10}
# Epoch 1/20
# WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 56/56 - 2s - loss: 0.4102 - sparse_categorical_crossentropy: 0.4029 - accuracy: 0.8569 - val_loss: 0.2978 - val_sparse_categorical_crossentropy: 0.2903 - val_accuracy: 0.8859
# Epoch 2/20
# 56/56 - 1s - loss: 0.3108 - sparse_categorical_crossentropy: 0.3033 - accuracy: 0.8880 - val_loss: 0.2794 - val_sparse_categorical_crossentropy: 0.2719 - val_accuracy: 0.8971
# Epoch 3/20
# 56/56 - 1s - loss: 0.2983 - sparse_categorical_crossentropy: 0.2908 - accuracy: 0.8910 - val_loss: 0.2660 - val_sparse_categorical_crossentropy: 0.2586 - val_accuracy: 0.9038
# Epoch 4/20
# 56/56 - 1s - loss: 0.2818 - sparse_categorical_crossentropy: 0.2743 - accuracy: 0.8955 - val_loss: 0.2560 - val_sparse_categorical_crossentropy: 0.2485 - val_accuracy: 0.9060
# Epoch 5/20
# 56/56 - 1s - loss: 0.2778 - sparse_categorical_crossentropy: 0.2703 - accuracy: 0.8997 - val_loss: 0.2714 - val_sparse_categorical_crossentropy: 0.2639 - val_accuracy: 0.9016
# Epoch 6/20
# 56/56 - 1s - loss: 0.2797 - sparse_categorical_crossentropy: 0.2722 - accuracy: 0.8966 - val_loss: 0.2563 - val_sparse_categorical_crossentropy: 0.2488 - val_accuracy: 0.9038
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2560 - sparse_categorical_crossentropy: 0.2485 - accuracy: 0.9060
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-20\assets
# --- Starting trial: run-21
# {'lambda': 5e-05, 'dropout': 0.2, 'run number': 1}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4421 - sparse_categorical_crossentropy: 0.4347 - accuracy: 0.8307 - val_loss: 0.3191 - val_sparse_categorical_crossentropy: 0.3116 - val_accuracy: 0.8747
# Epoch 2/20
# 56/56 - 1s - loss: 0.3286 - sparse_categorical_crossentropy: 0.3211 - accuracy: 0.8804 - val_loss: 0.2818 - val_sparse_categorical_crossentropy: 0.2743 - val_accuracy: 0.8949
# Epoch 3/20
# 56/56 - 1s - loss: 0.3057 - sparse_categorical_crossentropy: 0.2981 - accuracy: 0.8905 - val_loss: 0.2697 - val_sparse_categorical_crossentropy: 0.2621 - val_accuracy: 0.9038
# Epoch 4/20
# 56/56 - 1s - loss: 0.2974 - sparse_categorical_crossentropy: 0.2898 - accuracy: 0.8919 - val_loss: 0.2640 - val_sparse_categorical_crossentropy: 0.2564 - val_accuracy: 0.9016
# Epoch 5/20
# 56/56 - 1s - loss: 0.2878 - sparse_categorical_crossentropy: 0.2803 - accuracy: 0.8958 - val_loss: 0.2551 - val_sparse_categorical_crossentropy: 0.2475 - val_accuracy: 0.9083
# Epoch 6/20
# 56/56 - 1s - loss: 0.2724 - sparse_categorical_crossentropy: 0.2648 - accuracy: 0.8994 - val_loss: 0.2521 - val_sparse_categorical_crossentropy: 0.2445 - val_accuracy: 0.9060
# Epoch 7/20
# 56/56 - 1s - loss: 0.2738 - sparse_categorical_crossentropy: 0.2662 - accuracy: 0.8975 - val_loss: 0.2510 - val_sparse_categorical_crossentropy: 0.2434 - val_accuracy: 0.9083
# Epoch 8/20
# 56/56 - 1s - loss: 0.2701 - sparse_categorical_crossentropy: 0.2625 - accuracy: 0.9036 - val_loss: 0.2431 - val_sparse_categorical_crossentropy: 0.2355 - val_accuracy: 0.9105
# Epoch 9/20
# 56/56 - 1s - loss: 0.2669 - sparse_categorical_crossentropy: 0.2593 - accuracy: 0.8997 - val_loss: 0.2425 - val_sparse_categorical_crossentropy: 0.2350 - val_accuracy: 0.9105
# Epoch 10/20
# 56/56 - 1s - loss: 0.2674 - sparse_categorical_crossentropy: 0.2599 - accuracy: 0.9030 - val_loss: 0.2521 - val_sparse_categorical_crossentropy: 0.2445 - val_accuracy: 0.9083
# Epoch 11/20
# 56/56 - 1s - loss: 0.2717 - sparse_categorical_crossentropy: 0.2641 - accuracy: 0.9003 - val_loss: 0.2435 - val_sparse_categorical_crossentropy: 0.2360 - val_accuracy: 0.9128
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2425 - sparse_categorical_crossentropy: 0.2350 - accuracy: 0.9105
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-21\assets
# --- Starting trial: run-22
# {'lambda': 5e-05, 'dropout': 0.2, 'run number': 2}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4394 - sparse_categorical_crossentropy: 0.4319 - accuracy: 0.8276 - val_loss: 0.3153 - val_sparse_categorical_crossentropy: 0.3078 - val_accuracy: 0.8859
# Epoch 2/20
# 56/56 - 1s - loss: 0.3293 - sparse_categorical_crossentropy: 0.3218 - accuracy: 0.8840 - val_loss: 0.2918 - val_sparse_categorical_crossentropy: 0.2842 - val_accuracy: 0.8926
# Epoch 3/20
# 56/56 - 1s - loss: 0.3110 - sparse_categorical_crossentropy: 0.3034 - accuracy: 0.8880 - val_loss: 0.2780 - val_sparse_categorical_crossentropy: 0.2704 - val_accuracy: 0.8971
# Epoch 4/20
# 56/56 - 1s - loss: 0.2934 - sparse_categorical_crossentropy: 0.2857 - accuracy: 0.8916 - val_loss: 0.2598 - val_sparse_categorical_crossentropy: 0.2521 - val_accuracy: 0.9038
# Epoch 5/20
# 56/56 - 1s - loss: 0.2847 - sparse_categorical_crossentropy: 0.2771 - accuracy: 0.8977 - val_loss: 0.2568 - val_sparse_categorical_crossentropy: 0.2492 - val_accuracy: 0.9038
# Epoch 6/20
# 56/56 - 1s - loss: 0.2823 - sparse_categorical_crossentropy: 0.2747 - accuracy: 0.8969 - val_loss: 0.2592 - val_sparse_categorical_crossentropy: 0.2516 - val_accuracy: 0.9060
# Epoch 7/20
# 56/56 - 1s - loss: 0.2802 - sparse_categorical_crossentropy: 0.2725 - accuracy: 0.8991 - val_loss: 0.2506 - val_sparse_categorical_crossentropy: 0.2430 - val_accuracy: 0.9060
# Epoch 8/20
# 56/56 - 1s - loss: 0.2770 - sparse_categorical_crossentropy: 0.2694 - accuracy: 0.8986 - val_loss: 0.2455 - val_sparse_categorical_crossentropy: 0.2379 - val_accuracy: 0.9060
# Epoch 9/20
# 56/56 - 1s - loss: 0.2736 - sparse_categorical_crossentropy: 0.2660 - accuracy: 0.9003 - val_loss: 0.2438 - val_sparse_categorical_crossentropy: 0.2362 - val_accuracy: 0.9105
# Epoch 10/20
# 56/56 - 1s - loss: 0.2703 - sparse_categorical_crossentropy: 0.2627 - accuracy: 0.8997 - val_loss: 0.2471 - val_sparse_categorical_crossentropy: 0.2395 - val_accuracy: 0.9060
# Epoch 11/20
# 56/56 - 1s - loss: 0.2635 - sparse_categorical_crossentropy: 0.2559 - accuracy: 0.9022 - val_loss: 0.2425 - val_sparse_categorical_crossentropy: 0.2349 - val_accuracy: 0.9105
# Epoch 12/20
# 56/56 - 1s - loss: 0.2633 - sparse_categorical_crossentropy: 0.2557 - accuracy: 0.9042 - val_loss: 0.2512 - val_sparse_categorical_crossentropy: 0.2436 - val_accuracy: 0.9060
# Epoch 13/20
# 56/56 - 1s - loss: 0.2630 - sparse_categorical_crossentropy: 0.2554 - accuracy: 0.9047 - val_loss: 0.2465 - val_sparse_categorical_crossentropy: 0.2389 - val_accuracy: 0.9150
#  1/14 [=>............................] - ETA: 0s - loss: 0.3279 - sparse_categorical_crossentropy: 0.3202 - accuracy: 0.8750WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0141s). Check your callbacks.
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2425 - sparse_categorical_crossentropy: 0.2349 - accuracy: 0.9105
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-22\assets
# --- Starting trial: run-23
# {'lambda': 5e-05, 'dropout': 0.2, 'run number': 3}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4387 - sparse_categorical_crossentropy: 0.4314 - accuracy: 0.8430 - val_loss: 0.3109 - val_sparse_categorical_crossentropy: 0.3035 - val_accuracy: 0.8814
# Epoch 2/20
# 56/56 - 1s - loss: 0.3213 - sparse_categorical_crossentropy: 0.3139 - accuracy: 0.8843 - val_loss: 0.2748 - val_sparse_categorical_crossentropy: 0.2674 - val_accuracy: 0.8971
# Epoch 3/20
# 56/56 - 2s - loss: 0.3032 - sparse_categorical_crossentropy: 0.2958 - accuracy: 0.8902 - val_loss: 0.2645 - val_sparse_categorical_crossentropy: 0.2571 - val_accuracy: 0.8993
# Epoch 4/20
# 56/56 - 1s - loss: 0.3006 - sparse_categorical_crossentropy: 0.2931 - accuracy: 0.8896 - val_loss: 0.2666 - val_sparse_categorical_crossentropy: 0.2592 - val_accuracy: 0.9016
# Epoch 5/20
# 56/56 - 1s - loss: 0.2896 - sparse_categorical_crossentropy: 0.2822 - accuracy: 0.8966 - val_loss: 0.2544 - val_sparse_categorical_crossentropy: 0.2469 - val_accuracy: 0.9060
# Epoch 6/20
# 56/56 - 1s - loss: 0.2832 - sparse_categorical_crossentropy: 0.2758 - accuracy: 0.8994 - val_loss: 0.2584 - val_sparse_categorical_crossentropy: 0.2510 - val_accuracy: 0.9083
# Epoch 7/20
# 56/56 - 1s - loss: 0.2811 - sparse_categorical_crossentropy: 0.2737 - accuracy: 0.8947 - val_loss: 0.2616 - val_sparse_categorical_crossentropy: 0.2542 - val_accuracy: 0.9016
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2544 - sparse_categorical_crossentropy: 0.2469 - accuracy: 0.9060
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-23\assets
# --- Starting trial: run-24
# {'lambda': 5e-05, 'dropout': 0.2, 'run number': 4}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4281 - sparse_categorical_crossentropy: 0.4208 - accuracy: 0.8374 - val_loss: 0.3046 - val_sparse_categorical_crossentropy: 0.2973 - val_accuracy: 0.8837
# Epoch 2/20
# 56/56 - 1s - loss: 0.3306 - sparse_categorical_crossentropy: 0.3232 - accuracy: 0.8826 - val_loss: 0.2830 - val_sparse_categorical_crossentropy: 0.2756 - val_accuracy: 0.8971
# Epoch 3/20
# 56/56 - 1s - loss: 0.3069 - sparse_categorical_crossentropy: 0.2996 - accuracy: 0.8877 - val_loss: 0.2661 - val_sparse_categorical_crossentropy: 0.2587 - val_accuracy: 0.9038
# Epoch 4/20
# 56/56 - 1s - loss: 0.2977 - sparse_categorical_crossentropy: 0.2904 - accuracy: 0.8949 - val_loss: 0.2689 - val_sparse_categorical_crossentropy: 0.2616 - val_accuracy: 0.8971
# Epoch 5/20
# 56/56 - 1s - loss: 0.2921 - sparse_categorical_crossentropy: 0.2847 - accuracy: 0.8938 - val_loss: 0.2563 - val_sparse_categorical_crossentropy: 0.2490 - val_accuracy: 0.9038
# Epoch 6/20
# 56/56 - 1s - loss: 0.2857 - sparse_categorical_crossentropy: 0.2784 - accuracy: 0.8947 - val_loss: 0.2573 - val_sparse_categorical_crossentropy: 0.2499 - val_accuracy: 0.9060
# Epoch 7/20
# 56/56 - 1s - loss: 0.2785 - sparse_categorical_crossentropy: 0.2711 - accuracy: 0.8969 - val_loss: 0.2579 - val_sparse_categorical_crossentropy: 0.2505 - val_accuracy: 0.9060
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2563 - sparse_categorical_crossentropy: 0.2490 - accuracy: 0.9038
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-24\assets
# --- Starting trial: run-25
# {'lambda': 5e-05, 'dropout': 0.2, 'run number': 5}
# Epoch 1/20
# 56/56 - 1s - loss: 0.4269 - sparse_categorical_crossentropy: 0.4194 - accuracy: 0.8349 - val_loss: 0.3065 - val_sparse_categorical_crossentropy: 0.2990 - val_accuracy: 0.8837
# Epoch 2/20
# 56/56 - 1s - loss: 0.3220 - sparse_categorical_crossentropy: 0.3144 - accuracy: 0.8838 - val_loss: 0.2812 - val_sparse_categorical_crossentropy: 0.2736 - val_accuracy: 0.8993
# Epoch 3/20
# 56/56 - 1s - loss: 0.3022 - sparse_categorical_crossentropy: 0.2947 - accuracy: 0.8916 - val_loss: 0.2683 - val_sparse_categorical_crossentropy: 0.2607 - val_accuracy: 0.8993
# Epoch 4/20
# 56/56 - 1s - loss: 0.3013 - sparse_categorical_crossentropy: 0.2938 - accuracy: 0.8921 - val_loss: 0.2685 - val_sparse_categorical_crossentropy: 0.2609 - val_accuracy: 0.8971
# Epoch 5/20
# 56/56 - 1s - loss: 0.2854 - sparse_categorical_crossentropy: 0.2778 - accuracy: 0.8969 - val_loss: 0.2725 - val_sparse_categorical_crossentropy: 0.2650 - val_accuracy: 0.8971
# ...
# Epoch 9/20
# 56/56 - 1s - loss: 0.2819 - sparse_categorical_crossentropy: 0.2684 - accuracy: 0.8994 - val_loss: 0.2496 - val_sparse_categorical_crossentropy: 0.2363 - val_accuracy: 0.9128
# Epoch 10/20
# 56/56 - 1s - loss: 0.2773 - sparse_categorical_crossentropy: 0.2640 - accuracy: 0.9019 - val_loss: 0.2538 - val_sparse_categorical_crossentropy: 0.2405 - val_accuracy: 0.9105
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2477 - sparse_categorical_crossentropy: 0.2342 - accuracy: 0.9128
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-53\assets
# --- Starting trial: run-54
# {'lambda': 0.0001, 'dropout': 0.2, 'run number': 4}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4636 - sparse_categorical_crossentropy: 0.4491 - accuracy: 0.8226 - val_loss: 0.3278 - val_sparse_categorical_crossentropy: 0.3133 - val_accuracy: 0.8792
# Epoch 2/20
# 56/56 - 1s - loss: 0.3359 - sparse_categorical_crossentropy: 0.3215 - accuracy: 0.8810 - val_loss: 0.2942 - val_sparse_categorical_crossentropy: 0.2799 - val_accuracy: 0.8993
# Epoch 3/20
# 56/56 - 1s - loss: 0.3158 - sparse_categorical_crossentropy: 0.3015 - accuracy: 0.8913 - val_loss: 0.2667 - val_sparse_categorical_crossentropy: 0.2525 - val_accuracy: 0.9060
# Epoch 4/20
# 56/56 - 1s - loss: 0.3087 - sparse_categorical_crossentropy: 0.2946 - accuracy: 0.8902 - val_loss: 0.2617 - val_sparse_categorical_crossentropy: 0.2477 - val_accuracy: 0.9038
# Epoch 5/20
# 56/56 - 1s - loss: 0.2937 - sparse_categorical_crossentropy: 0.2797 - accuracy: 0.8977 - val_loss: 0.2585 - val_sparse_categorical_crossentropy: 0.2445 - val_accuracy: 0.9083
# Epoch 6/20
# 56/56 - 1s - loss: 0.2900 - sparse_categorical_crossentropy: 0.2761 - accuracy: 0.8961 - val_loss: 0.2551 - val_sparse_categorical_crossentropy: 0.2412 - val_accuracy: 0.9038
# Epoch 7/20
# 56/56 - 1s - loss: 0.2819 - sparse_categorical_crossentropy: 0.2681 - accuracy: 0.9005 - val_loss: 0.2765 - val_sparse_categorical_crossentropy: 0.2628 - val_accuracy: 0.9038
# Epoch 8/20
# 56/56 - 1s - loss: 0.2762 - sparse_categorical_crossentropy: 0.2625 - accuracy: 0.8997 - val_loss: 0.2587 - val_sparse_categorical_crossentropy: 0.2450 - val_accuracy: 0.9060
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2551 - sparse_categorical_crossentropy: 0.2412 - accuracy: 0.9038
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-54\assets
# --- Starting trial: run-55
# {'lambda': 0.0001, 'dropout': 0.2, 'run number': 5}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4413 - sparse_categorical_crossentropy: 0.4265 - accuracy: 0.8419 - val_loss: 0.3166 - val_sparse_categorical_crossentropy: 0.3017 - val_accuracy: 0.8814
# Epoch 2/20
# 56/56 - 1s - loss: 0.3389 - sparse_categorical_crossentropy: 0.3241 - accuracy: 0.8829 - val_loss: 0.2890 - val_sparse_categorical_crossentropy: 0.2743 - val_accuracy: 0.8971
# Epoch 3/20
# 56/56 - 1s - loss: 0.3166 - sparse_categorical_crossentropy: 0.3020 - accuracy: 0.8863 - val_loss: 0.2798 - val_sparse_categorical_crossentropy: 0.2652 - val_accuracy: 0.9038
# Epoch 4/20
# 56/56 - 1s - loss: 0.3056 - sparse_categorical_crossentropy: 0.2911 - accuracy: 0.8921 - val_loss: 0.2753 - val_sparse_categorical_crossentropy: 0.2609 - val_accuracy: 0.9038
# Epoch 5/20
# 56/56 - 1s - loss: 0.2980 - sparse_categorical_crossentropy: 0.2837 - accuracy: 0.8955 - val_loss: 0.2635 - val_sparse_categorical_crossentropy: 0.2492 - val_accuracy: 0.9060
# Epoch 6/20
# 56/56 - 1s - loss: 0.2945 - sparse_categorical_crossentropy: 0.2802 - accuracy: 0.8980 - val_loss: 0.2591 - val_sparse_categorical_crossentropy: 0.2449 - val_accuracy: 0.9083
# Epoch 7/20
# 56/56 - 1s - loss: 0.2847 - sparse_categorical_crossentropy: 0.2706 - accuracy: 0.8975 - val_loss: 0.2628 - val_sparse_categorical_crossentropy: 0.2488 - val_accuracy: 0.9060
# Epoch 8/20
# 56/56 - 1s - loss: 0.2827 - sparse_categorical_crossentropy: 0.2687 - accuracy: 0.9022 - val_loss: 0.2528 - val_sparse_categorical_crossentropy: 0.2388 - val_accuracy: 0.9105
# Epoch 9/20
# 56/56 - 1s - loss: 0.2745 - sparse_categorical_crossentropy: 0.2606 - accuracy: 0.9033 - val_loss: 0.2531 - val_sparse_categorical_crossentropy: 0.2392 - val_accuracy: 0.9083
# Epoch 10/20
# 56/56 - 1s - loss: 0.2760 - sparse_categorical_crossentropy: 0.2622 - accuracy: 0.9014 - val_loss: 0.2588 - val_sparse_categorical_crossentropy: 0.2450 - val_accuracy: 0.9060
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2528 - sparse_categorical_crossentropy: 0.2388 - accuracy: 0.9105
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-55\assets
# --- Starting trial: run-56
# {'lambda': 0.0001, 'dropout': 0.2, 'run number': 6}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4473 - sparse_categorical_crossentropy: 0.4326 - accuracy: 0.8335 - val_loss: 0.3147 - val_sparse_categorical_crossentropy: 0.2999 - val_accuracy: 0.8881
# Epoch 2/20
# 56/56 - 1s - loss: 0.3371 - sparse_categorical_crossentropy: 0.3224 - accuracy: 0.8807 - val_loss: 0.2857 - val_sparse_categorical_crossentropy: 0.2710 - val_accuracy: 0.8971
# Epoch 3/20
# 56/56 - 1s - loss: 0.3056 - sparse_categorical_crossentropy: 0.2910 - accuracy: 0.8933 - val_loss: 0.2753 - val_sparse_categorical_crossentropy: 0.2607 - val_accuracy: 0.9038
# Epoch 4/20
# 56/56 - 1s - loss: 0.3038 - sparse_categorical_crossentropy: 0.2893 - accuracy: 0.8927 - val_loss: 0.2722 - val_sparse_categorical_crossentropy: 0.2578 - val_accuracy: 0.9060
# Epoch 5/20
# 56/56 - 1s - loss: 0.2902 - sparse_categorical_crossentropy: 0.2758 - accuracy: 0.8966 - val_loss: 0.2614 - val_sparse_categorical_crossentropy: 0.2471 - val_accuracy: 0.9060
# Epoch 6/20
# 56/56 - 1s - loss: 0.2889 - sparse_categorical_crossentropy: 0.2746 - accuracy: 0.8980 - val_loss: 0.2646 - val_sparse_categorical_crossentropy: 0.2505 - val_accuracy: 0.9060
# Epoch 7/20
# 56/56 - 1s - loss: 0.2834 - sparse_categorical_crossentropy: 0.2693 - accuracy: 0.8997 - val_loss: 0.2531 - val_sparse_categorical_crossentropy: 0.2391 - val_accuracy: 0.9083
# Epoch 8/20
# 56/56 - 1s - loss: 0.2806 - sparse_categorical_crossentropy: 0.2666 - accuracy: 0.9011 - val_loss: 0.2559 - val_sparse_categorical_crossentropy: 0.2420 - val_accuracy: 0.9128
# Epoch 9/20
# 56/56 - 1s - loss: 0.2792 - sparse_categorical_crossentropy: 0.2653 - accuracy: 0.9019 - val_loss: 0.2544 - val_sparse_categorical_crossentropy: 0.2406 - val_accuracy: 0.9083
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2531 - sparse_categorical_crossentropy: 0.2391 - accuracy: 0.9083
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-56\assets
# --- Starting trial: run-57
# {'lambda': 0.0001, 'dropout': 0.2, 'run number': 7}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4632 - sparse_categorical_crossentropy: 0.4485 - accuracy: 0.8192 - val_loss: 0.3282 - val_sparse_categorical_crossentropy: 0.3135 - val_accuracy: 0.8837
# Epoch 2/20
# 56/56 - 1s - loss: 0.3399 - sparse_categorical_crossentropy: 0.3252 - accuracy: 0.8807 - val_loss: 0.2878 - val_sparse_categorical_crossentropy: 0.2733 - val_accuracy: 0.8971
# Epoch 3/20
# 56/56 - 1s - loss: 0.3157 - sparse_categorical_crossentropy: 0.3012 - accuracy: 0.8894 - val_loss: 0.2753 - val_sparse_categorical_crossentropy: 0.2609 - val_accuracy: 0.8993
# Epoch 4/20
# 56/56 - 1s - loss: 0.3053 - sparse_categorical_crossentropy: 0.2909 - accuracy: 0.8882 - val_loss: 0.2657 - val_sparse_categorical_crossentropy: 0.2513 - val_accuracy: 0.9083
# Epoch 5/20
# 56/56 - 1s - loss: 0.2976 - sparse_categorical_crossentropy: 0.2833 - accuracy: 0.8952 - val_loss: 0.2677 - val_sparse_categorical_crossentropy: 0.2534 - val_accuracy: 0.9060
# Epoch 6/20
# 56/56 - 1s - loss: 0.2858 - sparse_categorical_crossentropy: 0.2715 - accuracy: 0.8980 - val_loss: 0.2611 - val_sparse_categorical_crossentropy: 0.2470 - val_accuracy: 0.8993
# Epoch 7/20
# 56/56 - 1s - loss: 0.2905 - sparse_categorical_crossentropy: 0.2764 - accuracy: 0.8952 - val_loss: 0.2581 - val_sparse_categorical_crossentropy: 0.2441 - val_accuracy: 0.9060
# Epoch 8/20
# 56/56 - 1s - loss: 0.2826 - sparse_categorical_crossentropy: 0.2686 - accuracy: 0.9014 - val_loss: 0.2568 - val_sparse_categorical_crossentropy: 0.2429 - val_accuracy: 0.9083
# Epoch 9/20
# 56/56 - 1s - loss: 0.2876 - sparse_categorical_crossentropy: 0.2738 - accuracy: 0.8989 - val_loss: 0.2561 - val_sparse_categorical_crossentropy: 0.2423 - val_accuracy: 0.9060
# Epoch 10/20
# 56/56 - 1s - loss: 0.2807 - sparse_categorical_crossentropy: 0.2670 - accuracy: 0.9019 - val_loss: 0.2514 - val_sparse_categorical_crossentropy: 0.2378 - val_accuracy: 0.9083
# Epoch 11/20
# 56/56 - 1s - loss: 0.2727 - sparse_categorical_crossentropy: 0.2591 - accuracy: 0.9036 - val_loss: 0.2507 - val_sparse_categorical_crossentropy: 0.2371 - val_accuracy: 0.9105
# Epoch 12/20
# 56/56 - 1s - loss: 0.2671 - sparse_categorical_crossentropy: 0.2535 - accuracy: 0.9092 - val_loss: 0.2480 - val_sparse_categorical_crossentropy: 0.2345 - val_accuracy: 0.9105
# Epoch 13/20
# 56/56 - 1s - loss: 0.2716 - sparse_categorical_crossentropy: 0.2582 - accuracy: 0.9067 - val_loss: 0.2548 - val_sparse_categorical_crossentropy: 0.2414 - val_accuracy: 0.9083
# Epoch 14/20
# 56/56 - 1s - loss: 0.2645 - sparse_categorical_crossentropy: 0.2512 - accuracy: 0.9028 - val_loss: 0.2626 - val_sparse_categorical_crossentropy: 0.2493 - val_accuracy: 0.9105
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2480 - sparse_categorical_crossentropy: 0.2345 - accuracy: 0.9105
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-57\assets
# --- Starting trial: run-58
# {'lambda': 0.0001, 'dropout': 0.2, 'run number': 8}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4492 - sparse_categorical_crossentropy: 0.4347 - accuracy: 0.8270 - val_loss: 0.3107 - val_sparse_categorical_crossentropy: 0.2961 - val_accuracy: 0.8881
# Epoch 2/20
# 56/56 - 1s - loss: 0.3294 - sparse_categorical_crossentropy: 0.3150 - accuracy: 0.8813 - val_loss: 0.2876 - val_sparse_categorical_crossentropy: 0.2733 - val_accuracy: 0.8993
# Epoch 3/20
# 56/56 - 1s - loss: 0.3096 - sparse_categorical_crossentropy: 0.2954 - accuracy: 0.8927 - val_loss: 0.2789 - val_sparse_categorical_crossentropy: 0.2648 - val_accuracy: 0.8993
# Epoch 4/20
# 56/56 - 1s - loss: 0.3020 - sparse_categorical_crossentropy: 0.2879 - accuracy: 0.8894 - val_loss: 0.2661 - val_sparse_categorical_crossentropy: 0.2521 - val_accuracy: 0.9060
# Epoch 5/20
# 56/56 - 1s - loss: 0.2929 - sparse_categorical_crossentropy: 0.2790 - accuracy: 0.8947 - val_loss: 0.2646 - val_sparse_categorical_crossentropy: 0.2508 - val_accuracy: 0.9038
# Epoch 6/20
# 56/56 - 1s - loss: 0.2923 - sparse_categorical_crossentropy: 0.2785 - accuracy: 0.8966 - val_loss: 0.2590 - val_sparse_categorical_crossentropy: 0.2453 - val_accuracy: 0.9060
# Epoch 7/20
# 56/56 - 1s - loss: 0.2830 - sparse_categorical_crossentropy: 0.2694 - accuracy: 0.9014 - val_loss: 0.2549 - val_sparse_categorical_crossentropy: 0.2412 - val_accuracy: 0.9060
# Epoch 8/20
# 56/56 - 1s - loss: 0.2830 - sparse_categorical_crossentropy: 0.2695 - accuracy: 0.8983 - val_loss: 0.2508 - val_sparse_categorical_crossentropy: 0.2374 - val_accuracy: 0.9083
# Epoch 9/20
# 56/56 - 1s - loss: 0.2789 - sparse_categorical_crossentropy: 0.2656 - accuracy: 0.9030 - val_loss: 0.2497 - val_sparse_categorical_crossentropy: 0.2364 - val_accuracy: 0.9150
# Epoch 10/20
# 56/56 - 1s - loss: 0.2728 - sparse_categorical_crossentropy: 0.2595 - accuracy: 0.9016 - val_loss: 0.2551 - val_sparse_categorical_crossentropy: 0.2419 - val_accuracy: 0.9128
# Epoch 11/20
# 56/56 - 1s - loss: 0.2787 - sparse_categorical_crossentropy: 0.2656 - accuracy: 0.9005 - val_loss: 0.2488 - val_sparse_categorical_crossentropy: 0.2357 - val_accuracy: 0.9128
# Epoch 12/20
# 56/56 - 1s - loss: 0.2679 - sparse_categorical_crossentropy: 0.2548 - accuracy: 0.9044 - val_loss: 0.2515 - val_sparse_categorical_crossentropy: 0.2385 - val_accuracy: 0.9105
# Epoch 13/20
# 56/56 - 1s - loss: 0.2683 - sparse_categorical_crossentropy: 0.2553 - accuracy: 0.9033 - val_loss: 0.2461 - val_sparse_categorical_crossentropy: 0.2332 - val_accuracy: 0.9150
# Epoch 14/20
# 56/56 - 1s - loss: 0.2691 - sparse_categorical_crossentropy: 0.2563 - accuracy: 0.9030 - val_loss: 0.2501 - val_sparse_categorical_crossentropy: 0.2372 - val_accuracy: 0.9105
# Epoch 15/20
# 56/56 - 1s - loss: 0.2658 - sparse_categorical_crossentropy: 0.2530 - accuracy: 0.9075 - val_loss: 0.2458 - val_sparse_categorical_crossentropy: 0.2330 - val_accuracy: 0.9128
# Epoch 16/20
# 56/56 - 1s - loss: 0.2575 - sparse_categorical_crossentropy: 0.2448 - accuracy: 0.9092 - val_loss: 0.2509 - val_sparse_categorical_crossentropy: 0.2382 - val_accuracy: 0.9150
# Epoch 17/20
# 56/56 - 1s - loss: 0.2677 - sparse_categorical_crossentropy: 0.2551 - accuracy: 0.9056 - val_loss: 0.2410 - val_sparse_categorical_crossentropy: 0.2285 - val_accuracy: 0.9172
# Epoch 18/20
# 56/56 - 1s - loss: 0.2584 - sparse_categorical_crossentropy: 0.2459 - accuracy: 0.9064 - val_loss: 0.2559 - val_sparse_categorical_crossentropy: 0.2434 - val_accuracy: 0.9128
# Epoch 19/20
# 56/56 - 1s - loss: 0.2618 - sparse_categorical_crossentropy: 0.2493 - accuracy: 0.9075 - val_loss: 0.2455 - val_sparse_categorical_crossentropy: 0.2330 - val_accuracy: 0.9150
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2410 - sparse_categorical_crossentropy: 0.2285 - accuracy: 0.9172
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-58\assets
# --- Starting trial: run-59
# {'lambda': 0.0001, 'dropout': 0.2, 'run number': 9}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4573 - sparse_categorical_crossentropy: 0.4425 - accuracy: 0.8318 - val_loss: 0.3138 - val_sparse_categorical_crossentropy: 0.2989 - val_accuracy: 0.8770
# Epoch 2/20
# 56/56 - 1s - loss: 0.3240 - sparse_categorical_crossentropy: 0.3093 - accuracy: 0.8840 - val_loss: 0.2819 - val_sparse_categorical_crossentropy: 0.2672 - val_accuracy: 0.9038
# Epoch 3/20
# 56/56 - 1s - loss: 0.3100 - sparse_categorical_crossentropy: 0.2954 - accuracy: 0.8941 - val_loss: 0.2707 - val_sparse_categorical_crossentropy: 0.2562 - val_accuracy: 0.8993
# Epoch 4/20
# 56/56 - 1s - loss: 0.3089 - sparse_categorical_crossentropy: 0.2944 - accuracy: 0.8899 - val_loss: 0.2752 - val_sparse_categorical_crossentropy: 0.2608 - val_accuracy: 0.8993
# Epoch 5/20
# 56/56 - 1s - loss: 0.2977 - sparse_categorical_crossentropy: 0.2833 - accuracy: 0.8949 - val_loss: 0.2765 - val_sparse_categorical_crossentropy: 0.2623 - val_accuracy: 0.9016
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2707 - sparse_categorical_crossentropy: 0.2562 - accuracy: 0.8993
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-59\assets
# --- Starting trial: run-60
# {'lambda': 0.0001, 'dropout': 0.2, 'run number': 10}
# Epoch 1/20
# 56/56 - 2s - loss: 0.4583 - sparse_categorical_crossentropy: 0.4436 - accuracy: 0.8324 - val_loss: 0.3251 - val_sparse_categorical_crossentropy: 0.3103 - val_accuracy: 0.8792
# Epoch 2/20
# 56/56 - 1s - loss: 0.3356 - sparse_categorical_crossentropy: 0.3208 - accuracy: 0.8824 - val_loss: 0.2891 - val_sparse_categorical_crossentropy: 0.2744 - val_accuracy: 0.8904
# Epoch 3/20
# 56/56 - 1s - loss: 0.3174 - sparse_categorical_crossentropy: 0.3027 - accuracy: 0.8852 - val_loss: 0.2774 - val_sparse_categorical_crossentropy: 0.2628 - val_accuracy: 0.8993
# Epoch 4/20
# 56/56 - 1s - loss: 0.3035 - sparse_categorical_crossentropy: 0.2890 - accuracy: 0.8921 - val_loss: 0.2674 - val_sparse_categorical_crossentropy: 0.2530 - val_accuracy: 0.8993
# Epoch 5/20
# 56/56 - 1s - loss: 0.2988 - sparse_categorical_crossentropy: 0.2844 - accuracy: 0.8949 - val_loss: 0.2637 - val_sparse_categorical_crossentropy: 0.2493 - val_accuracy: 0.9060
# Epoch 6/20
# 56/56 - 1s - loss: 0.2885 - sparse_categorical_crossentropy: 0.2741 - accuracy: 0.8972 - val_loss: 0.2638 - val_sparse_categorical_crossentropy: 0.2495 - val_accuracy: 0.9016
# Epoch 7/20
# 56/56 - 1s - loss: 0.2831 - sparse_categorical_crossentropy: 0.2689 - accuracy: 0.8989 - val_loss: 0.2746 - val_sparse_categorical_crossentropy: 0.2604 - val_accuracy: 0.8993
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2637 - sparse_categorical_crossentropy: 0.2493 - accuracy: 0.9060
# INFO:tensorflow:Assets written to: saved_models\Model 3\Run-60\assets

# %%
# %load_ext tensorboard
# %tensorboard --logdir "Logs/Model 3/hparam_tuning"
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 4956), started 0:00:57 ago. (Use '!kill 4956' to kill it.)
#       <iframe id="tensorboard-frame-3c45934a2a1a2bec" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-3c45934a2a1a2bec");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %load_ext tensorboard
# %tensorboard --logdir "Logs/Model 3/fit"
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 9020), started 0:01:02 ago. (Use '!kill 9020' to kill it.)
#       <iframe id="tensorboard-frame-25de94b11c6ed39f" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-25de94b11c6ed39f");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Test the model

# %%
# Loading a model to evaluate on the test set
model = tf.keras.models.load_model(r"saved_models\Model 3\Run-33")

# %%
test_pred = np.argmax(model.predict(test_inputs), axis=1)
test_accuracy = (test_targets == test_pred).sum() / test_targets.shape[0]

# %%
print('\nTest accuracy: {0:.2f}%'.format(test_accuracy * 100.))
# Out:
# Test accuracy: 91.52%
