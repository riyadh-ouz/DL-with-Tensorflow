# %% [markdown]
# # Practical example. Audiobooks

# %% [markdown]
# ## Create the machine learning algorithm, HParams Tuning

# %% [markdown]
# ### Import the relevant libraries

# %%
import io
import itertools

import numpy as np
import sklearn.metrics

import tensorflow as tf
from tensorboard.plugins.hparams import api as hp

import matplotlib.pyplot as plt

# %% [markdown]
# ### Data

# %%
npz = np.load('Audiobooks_data_train.npz')

train_inputs = npz['inputs'].astype(np.float)
train_targets = npz['targets'].astype(np.int)

npz = np.load('Audiobooks_data_validation.npz')
validation_inputs, validation_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

npz = np.load('Audiobooks_data_test.npz')
test_inputs, test_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

# %% [markdown]
# ### Model
# Outline, optimizers, loss, early stopping and training

# %%
max_epochs = 20
batch_size = 64

input_size = 10
output_size = 2

# %%
HP_ACTIVATION = hp.HParam('activation_function', hp.Discrete(['sigmoid', 'relu']))
HP_HIDDEN_LAYER_SIZE = hp.HParam('hidden_layer_size', hp.Discrete([32, 64, 96, 128]))

with tf.summary.create_file_writer(r'Logs/Model 1/hparam_tuning/').as_default():
    hp.hparams_config(
        hparams = [HP_ACTIVATION, HP_HIDDEN_LAYER_SIZE],
        metrics = [hp.Metric('accuracy', display_name = 'Accuracy')]
    )

# %%
# Wrapping our model and training in a function
def train_test_model(hparams, session_num):
    
    # Outlining the model/architecture of our CNN
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(hparams[HP_HIDDEN_LAYER_SIZE], hparams[HP_ACTIVATION]),
        tf.keras.layers.Dense(hparams[HP_HIDDEN_LAYER_SIZE], hparams[HP_ACTIVATION]),
        tf.keras.layers.Dense(output_size, activation='softmax')
    ])
    
    # Defining the loss function
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy()
    
    # Compiling the model
    model.compile(optimizer='adam', loss=loss_fn, metrics=['accuracy'])
    
    # Defining the logging directory
    log_dir = r'Logs/Model 1/fit/' + 'run-{}'.format(session_num)

    
    def plot_confusion_matrix(cm, class_names):
        """
        Returns a matplotlib figure containing the plotted confusion matrix.

        Args:
          cm (array, shape = [n, n]): a confusion matrix of integer classes
          class_names (array, shape = [n]): String names of the integer classes
        """
        figure = plt.figure(figsize=(12, 12))
        plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
        plt.title("Confusion matrix")
        plt.colorbar()
        tick_marks = np.arange(len(class_names))
        plt.xticks(tick_marks, class_names, rotation=45)
        plt.yticks(tick_marks, class_names)

        # Normalize the confusion matrix.
        cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)

        # Use white text if squares are dark; otherwise black.
        threshold = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            color = "white" if cm[i, j] > threshold else "black"
            plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)

        plt.tight_layout()
        plt.ylabel('True label')
        plt.xlabel('Predicted label')
        return figure
    
    def plot_to_image(figure):
        """Converts the matplotlib plot specified by 'figure' to a PNG image and
        returns it. The supplied figure is closed and inaccessible after this call."""
        # Save the plot to a PNG in memory.
        buf = io.BytesIO()
        plt.savefig(buf, format='png')
        # Closing the figure prevents it from being displayed directly inside
        # the notebook.
        plt.close(figure)
        buf.seek(0)
        # Convert PNG buffer to TF image
        image = tf.image.decode_png(buf.getvalue(), channels=4)
        # Add the batch dimension
        image = tf.expand_dims(image, 0)
        return image
    
    
    # Defining a file writer for Confusion Matrix logging purposes
    file_writer_cm = tf.summary.create_file_writer(log_dir + '/cm')     
    
    
    def log_confusion_matrix(epoch, logs):
        # Use the model to predict the values from the validation dataset.
        test_pred_raw = model.predict(validation_inputs)
        test_pred = np.argmax(test_pred_raw, axis=1)

        # Calculate the confusion matrix.
        cm = sklearn.metrics.confusion_matrix(validation_targets, test_pred)
        # Log the confusion matrix as an image summary.
        figure = plot_confusion_matrix(cm, class_names=["won't buy", "will buy"])
        cm_image = plot_to_image(figure)

        # Log the confusion matrix as an image summary.
        with file_writer_cm.as_default():
            tf.summary.image("Confusion Matrix", cm_image, step=epoch)
    
    
    
    # Define the Tensorboard and Confusion Matrix callbacks.
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, profile_batch=0)
    cm_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end=log_confusion_matrix)

    
    # Defining early stopping to prevent overfitting
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor = 'val_loss',
        mode = 'auto',
        min_delta = 0,
        patience = 2,
        verbose = 0, 
        restore_best_weights = True
    )
    
    # Training the model
    model.fit(
        train_inputs,
        train_targets,
        epochs = max_epochs,
        batch_size = batch_size,
        callbacks = [tensorboard_callback, cm_callback, early_stopping],
        validation_data = (validation_inputs, validation_targets),
        verbose = 2
    )
    
    
    # Evaluating the model's performance on the validation set
    _, accuracy = model.evaluate(validation_inputs, validation_targets)
    
    # Saving the current model for future reference
    model.save(r'saved_models\Model 1\Run-{}'.format(session_num))
    
    return accuracy

# %%
# Creating a function to log the resuls
def run(log_dir, hparams, session_num):
    
    with tf.summary.create_file_writer(log_dir).as_default():
        hp.hparams(hparams)
        accuracy = train_test_model(hparams, session_num)
        tf.summary.scalar('accuracy', accuracy, step=1)

# %%
session_num = 1

for activation in HP_ACTIVATION.domain.values:
    for hidden_layer_size in HP_HIDDEN_LAYER_SIZE.domain.values:
        
        hparams = {
            HP_ACTIVATION: activation,
            HP_HIDDEN_LAYER_SIZE: hidden_layer_size
        }

        run_name = "run-%d" % session_num
        print('--- Starting trial: %s' % run_name)
        print({h.name: hparams[h] for h in hparams})
        run('Logs/Model 1/hparam_tuning/' + run_name, hparams, session_num)

        session_num += 1
# Out:
# --- Starting trial: run-1
# {'activation_function': 'relu', 'hidden_layer_size': 32}
# Epoch 1/20
# 56/56 - 1s - loss: 0.5654 - accuracy: 0.7603 - val_loss: 0.4294 - val_accuracy: 0.8792
# Epoch 2/20
# 56/56 - 1s - loss: 0.3639 - accuracy: 0.8737 - val_loss: 0.3096 - val_accuracy: 0.8904
# Epoch 3/20
# 56/56 - 1s - loss: 0.3122 - accuracy: 0.8821 - val_loss: 0.2878 - val_accuracy: 0.8971
# Epoch 4/20
# 56/56 - 1s - loss: 0.2927 - accuracy: 0.8905 - val_loss: 0.2674 - val_accuracy: 0.8993
# Epoch 5/20
# 56/56 - 0s - loss: 0.2798 - accuracy: 0.8952 - val_loss: 0.2599 - val_accuracy: 0.9016
# Epoch 6/20
# 56/56 - 1s - loss: 0.2719 - accuracy: 0.8994 - val_loss: 0.2534 - val_accuracy: 0.9060
# Epoch 7/20
# 56/56 - 0s - loss: 0.2654 - accuracy: 0.9003 - val_loss: 0.2494 - val_accuracy: 0.9083
# Epoch 8/20
# 56/56 - 1s - loss: 0.2597 - accuracy: 0.9025 - val_loss: 0.2501 - val_accuracy: 0.9105
# Epoch 9/20
# 56/56 - 1s - loss: 0.2572 - accuracy: 0.9030 - val_loss: 0.2475 - val_accuracy: 0.9038
# Epoch 10/20
# 56/56 - 0s - loss: 0.2543 - accuracy: 0.9036 - val_loss: 0.2459 - val_accuracy: 0.9105
# Epoch 11/20
# 56/56 - 1s - loss: 0.2495 - accuracy: 0.9067 - val_loss: 0.2438 - val_accuracy: 0.9083
# Epoch 12/20
# 56/56 - 1s - loss: 0.2481 - accuracy: 0.9056 - val_loss: 0.2382 - val_accuracy: 0.9128
# Epoch 13/20
# 56/56 - 1s - loss: 0.2444 - accuracy: 0.9061 - val_loss: 0.2389 - val_accuracy: 0.9105
# Epoch 14/20
# 56/56 - 1s - loss: 0.2442 - accuracy: 0.9084 - val_loss: 0.2414 - val_accuracy: 0.9083
# 14/14 [==============================] - 0s 926us/step - loss: 0.2382 - accuracy: 0.9128
# WARNING:tensorflow:From C:\Users\pc\anaconda3\envs\tf\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\pc\anaconda3\envs\tf\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: saved_models\Model 1\Run-1\assets
# --- Starting trial: run-2
# {'activation_function': 'relu', 'hidden_layer_size': 64}
# Epoch 1/20
# 56/56 - 1s - loss: 0.4611 - accuracy: 0.8217 - val_loss: 0.3329 - val_accuracy: 0.8814
# Epoch 2/20
# 56/56 - 1s - loss: 0.3200 - accuracy: 0.8813 - val_loss: 0.2837 - val_accuracy: 0.8926
# Epoch 3/20
# 56/56 - 1s - loss: 0.2952 - accuracy: 0.8905 - val_loss: 0.2687 - val_accuracy: 0.9016
# Epoch 4/20
# 56/56 - 1s - loss: 0.2802 - accuracy: 0.8941 - val_loss: 0.2573 - val_accuracy: 0.9016
# Epoch 5/20
# 56/56 - 1s - loss: 0.2733 - accuracy: 0.8969 - val_loss: 0.2614 - val_accuracy: 0.9016
# Epoch 6/20
# 56/56 - 1s - loss: 0.2657 - accuracy: 0.8997 - val_loss: 0.2569 - val_accuracy: 0.9016
# Epoch 7/20
# 56/56 - 1s - loss: 0.2621 - accuracy: 0.8994 - val_loss: 0.2442 - val_accuracy: 0.9060
# Epoch 8/20
# 56/56 - 0s - loss: 0.2575 - accuracy: 0.9025 - val_loss: 0.2462 - val_accuracy: 0.9105
# Epoch 9/20
# 56/56 - 1s - loss: 0.2532 - accuracy: 0.9050 - val_loss: 0.2458 - val_accuracy: 0.9083
# 14/14 [==============================] - 0s 715us/step - loss: 0.2442 - accuracy: 0.9060
# INFO:tensorflow:Assets written to: saved_models\Model 1\Run-2\assets
# --- Starting trial: run-3
# {'activation_function': 'relu', 'hidden_layer_size': 96}
# Epoch 1/20
# 56/56 - 1s - loss: 0.4237 - accuracy: 0.8536 - val_loss: 0.2992 - val_accuracy: 0.8837
# Epoch 2/20
# 56/56 - 1s - loss: 0.3059 - accuracy: 0.8857 - val_loss: 0.2747 - val_accuracy: 0.8971
# Epoch 3/20
# 56/56 - 1s - loss: 0.2840 - accuracy: 0.8963 - val_loss: 0.2616 - val_accuracy: 0.9038
# Epoch 4/20
# 56/56 - 1s - loss: 0.2729 - accuracy: 0.9000 - val_loss: 0.2488 - val_accuracy: 0.9060
# Epoch 5/20
# 56/56 - 1s - loss: 0.2593 - accuracy: 0.9016 - val_loss: 0.2425 - val_accuracy: 0.9038
# Epoch 6/20
# 56/56 - 0s - loss: 0.2524 - accuracy: 0.9036 - val_loss: 0.2325 - val_accuracy: 0.9083
# Epoch 7/20
# 56/56 - 1s - loss: 0.2492 - accuracy: 0.9061 - val_loss: 0.2382 - val_accuracy: 0.9128
# Epoch 8/20
# 56/56 - 0s - loss: 0.2468 - accuracy: 0.9047 - val_loss: 0.2344 - val_accuracy: 0.9150
# 14/14 [==============================] - 0s 712us/step - loss: 0.2325 - accuracy: 0.9083
# INFO:tensorflow:Assets written to: saved_models\Model 1\Run-3\assets
# --- Starting trial: run-4
# {'activation_function': 'relu', 'hidden_layer_size': 128}
# Epoch 1/20
# 56/56 - 1s - loss: 0.3911 - accuracy: 0.8692 - val_loss: 0.2988 - val_accuracy: 0.8881
# Epoch 2/20
# 56/56 - 1s - loss: 0.2981 - accuracy: 0.8885 - val_loss: 0.2744 - val_accuracy: 0.8971
# Epoch 3/20
# 56/56 - 1s - loss: 0.2764 - accuracy: 0.8966 - val_loss: 0.2494 - val_accuracy: 0.9083
# Epoch 4/20
# 56/56 - 1s - loss: 0.2596 - accuracy: 0.9008 - val_loss: 0.2563 - val_accuracy: 0.9105
# Epoch 5/20
# 56/56 - 1s - loss: 0.2606 - accuracy: 0.9028 - val_loss: 0.2375 - val_accuracy: 0.9128
# Epoch 6/20
# 56/56 - 0s - loss: 0.2537 - accuracy: 0.9036 - val_loss: 0.2433 - val_accuracy: 0.9105
# Epoch 7/20
# 56/56 - 1s - loss: 0.2487 - accuracy: 0.9058 - val_loss: 0.2477 - val_accuracy: 0.9038
# 14/14 [==============================] - 0s 784us/step - loss: 0.2375 - accuracy: 0.9128
# INFO:tensorflow:Assets written to: saved_models\Model 1\Run-4\assets
# --- Starting trial: run-5
# {'activation_function': 'sigmoid', 'hidden_layer_size': 32}
# Epoch 1/20
# 56/56 - 1s - loss: 0.6706 - accuracy: 0.6778 - val_loss: 0.6456 - val_accuracy: 0.8479
# Epoch 2/20
# 56/56 - 1s - loss: 0.6100 - accuracy: 0.8502 - val_loss: 0.5656 - val_accuracy: 0.8613
# Epoch 3/20
# 56/56 - 1s - loss: 0.5100 - accuracy: 0.8589 - val_loss: 0.4505 - val_accuracy: 0.8725
# Epoch 4/20
# 56/56 - 1s - loss: 0.4102 - accuracy: 0.8737 - val_loss: 0.3673 - val_accuracy: 0.8792
# Epoch 5/20
# 56/56 - 0s - loss: 0.3553 - accuracy: 0.8779 - val_loss: 0.3307 - val_accuracy: 0.8859
# Epoch 6/20
# 56/56 - 1s - loss: 0.3327 - accuracy: 0.8801 - val_loss: 0.3117 - val_accuracy: 0.8837
# Epoch 7/20
# 56/56 - 1s - loss: 0.3246 - accuracy: 0.8818 - val_loss: 0.3032 - val_accuracy: 0.8814
# Epoch 8/20
# 56/56 - 1s - loss: 0.3198 - accuracy: 0.8840 - val_loss: 0.2955 - val_accuracy: 0.8837
# Epoch 9/20
# 56/56 - 1s - loss: 0.3133 - accuracy: 0.8854 - val_loss: 0.2900 - val_accuracy: 0.8881
# Epoch 10/20
# 56/56 - 1s - loss: 0.3101 - accuracy: 0.8868 - val_loss: 0.2902 - val_accuracy: 0.8926
# Epoch 11/20
# 56/56 - 1s - loss: 0.3071 - accuracy: 0.8871 - val_loss: 0.2862 - val_accuracy: 0.8949
# Epoch 12/20
# 56/56 - 1s - loss: 0.3031 - accuracy: 0.8894 - val_loss: 0.2818 - val_accuracy: 0.8993
# Epoch 13/20
# 56/56 - 0s - loss: 0.3010 - accuracy: 0.8910 - val_loss: 0.2749 - val_accuracy: 0.8949
# Epoch 14/20
# 56/56 - 0s - loss: 0.2988 - accuracy: 0.8916 - val_loss: 0.2720 - val_accuracy: 0.8971
# Epoch 15/20
# 56/56 - 1s - loss: 0.2976 - accuracy: 0.8927 - val_loss: 0.2740 - val_accuracy: 0.9016
# Epoch 16/20
# 56/56 - 1s - loss: 0.2942 - accuracy: 0.8905 - val_loss: 0.2710 - val_accuracy: 0.8993
# Epoch 17/20
# 56/56 - 1s - loss: 0.2923 - accuracy: 0.8921 - val_loss: 0.2647 - val_accuracy: 0.8993
# Epoch 18/20
# 56/56 - 1s - loss: 0.2910 - accuracy: 0.8952 - val_loss: 0.2631 - val_accuracy: 0.9038
# Epoch 19/20
# 56/56 - 1s - loss: 0.2888 - accuracy: 0.8947 - val_loss: 0.2610 - val_accuracy: 0.8993
# Epoch 20/20
# 56/56 - 1s - loss: 0.2868 - accuracy: 0.8969 - val_loss: 0.2607 - val_accuracy: 0.9060
# 14/14 [==============================] - 0s 854us/step - loss: 0.2607 - accuracy: 0.9060
# INFO:tensorflow:Assets written to: saved_models\Model 1\Run-5\assets
# --- Starting trial: run-6
# {'activation_function': 'sigmoid', 'hidden_layer_size': 64}
# Epoch 1/20
# 56/56 - 1s - loss: 0.6475 - accuracy: 0.6918 - val_loss: 0.5960 - val_accuracy: 0.7763
# Epoch 2/20
# 56/56 - 1s - loss: 0.5266 - accuracy: 0.8519 - val_loss: 0.4582 - val_accuracy: 0.8770
# Epoch 3/20
# 56/56 - 1s - loss: 0.4116 - accuracy: 0.8720 - val_loss: 0.3634 - val_accuracy: 0.8814
# Epoch 4/20
# 56/56 - 1s - loss: 0.3532 - accuracy: 0.8765 - val_loss: 0.3254 - val_accuracy: 0.8881
# Epoch 5/20
# 56/56 - 1s - loss: 0.3324 - accuracy: 0.8796 - val_loss: 0.3074 - val_accuracy: 0.8837
# Epoch 6/20
# 56/56 - 0s - loss: 0.3226 - accuracy: 0.8846 - val_loss: 0.2981 - val_accuracy: 0.8837
# Epoch 7/20
# 56/56 - 1s - loss: 0.3177 - accuracy: 0.8857 - val_loss: 0.2934 - val_accuracy: 0.8859
# Epoch 8/20
# 56/56 - 1s - loss: 0.3121 - accuracy: 0.8857 - val_loss: 0.2890 - val_accuracy: 0.8949
# Epoch 9/20
# 56/56 - 1s - loss: 0.3093 - accuracy: 0.8882 - val_loss: 0.2812 - val_accuracy: 0.8949
# Epoch 10/20
# 56/56 - 1s - loss: 0.3057 - accuracy: 0.8891 - val_loss: 0.2819 - val_accuracy: 0.8971
# Epoch 11/20
# 56/56 - 1s - loss: 0.3012 - accuracy: 0.8888 - val_loss: 0.2769 - val_accuracy: 0.8971
# Epoch 12/20
# 56/56 - 1s - loss: 0.3002 - accuracy: 0.8905 - val_loss: 0.2754 - val_accuracy: 0.8993
# Epoch 13/20
# 56/56 - 1s - loss: 0.2956 - accuracy: 0.8924 - val_loss: 0.2813 - val_accuracy: 0.8904
# Epoch 14/20
# 56/56 - 1s - loss: 0.2962 - accuracy: 0.8919 - val_loss: 0.2667 - val_accuracy: 0.9038
# Epoch 15/20
# 56/56 - 1s - loss: 0.2945 - accuracy: 0.8882 - val_loss: 0.2653 - val_accuracy: 0.9060
# Epoch 16/20
# 56/56 - 0s - loss: 0.2903 - accuracy: 0.8935 - val_loss: 0.2620 - val_accuracy: 0.9038
# Epoch 17/20
# 56/56 - 1s - loss: 0.2876 - accuracy: 0.8963 - val_loss: 0.2605 - val_accuracy: 0.9016
# Epoch 18/20
# 56/56 - 0s - loss: 0.2876 - accuracy: 0.8958 - val_loss: 0.2585 - val_accuracy: 0.9060
# Epoch 19/20
# 56/56 - 0s - loss: 0.2844 - accuracy: 0.8966 - val_loss: 0.2575 - val_accuracy: 0.9038
# Epoch 20/20
# 56/56 - 1s - loss: 0.2859 - accuracy: 0.8952 - val_loss: 0.2595 - val_accuracy: 0.9060
# 14/14 [==============================] - 0s 857us/step - loss: 0.2595 - accuracy: 0.9060
# INFO:tensorflow:Assets written to: saved_models\Model 1\Run-6\assets
# --- Starting trial: run-7
# {'activation_function': 'sigmoid', 'hidden_layer_size': 96}
# Epoch 1/20
# WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 56/56 - 1s - loss: 0.6546 - accuracy: 0.6533 - val_loss: 0.5890 - val_accuracy: 0.8702
# Epoch 2/20
# 56/56 - 1s - loss: 0.5134 - accuracy: 0.8469 - val_loss: 0.4341 - val_accuracy: 0.8814
# Epoch 3/20
# 56/56 - 1s - loss: 0.3912 - accuracy: 0.8712 - val_loss: 0.3489 - val_accuracy: 0.8881
# Epoch 4/20
# 56/56 - 1s - loss: 0.3412 - accuracy: 0.8785 - val_loss: 0.3180 - val_accuracy: 0.8859
# Epoch 5/20
# 56/56 - 0s - loss: 0.3231 - accuracy: 0.8832 - val_loss: 0.3090 - val_accuracy: 0.8859
# Epoch 6/20
# 56/56 - 0s - loss: 0.3163 - accuracy: 0.8863 - val_loss: 0.2899 - val_accuracy: 0.8904
# Epoch 7/20
# 56/56 - 1s - loss: 0.3109 - accuracy: 0.8866 - val_loss: 0.2839 - val_accuracy: 0.8926
# Epoch 8/20
# 56/56 - 1s - loss: 0.3067 - accuracy: 0.8888 - val_loss: 0.2817 - val_accuracy: 0.8949
# Epoch 9/20
# 56/56 - 1s - loss: 0.3024 - accuracy: 0.8880 - val_loss: 0.2739 - val_accuracy: 0.8949
# Epoch 10/20
# 56/56 - 1s - loss: 0.2992 - accuracy: 0.8908 - val_loss: 0.2797 - val_accuracy: 0.8993
# Epoch 11/20
# 56/56 - 1s - loss: 0.2963 - accuracy: 0.8913 - val_loss: 0.2676 - val_accuracy: 0.8993
# Epoch 12/20
# 56/56 - 1s - loss: 0.2935 - accuracy: 0.8919 - val_loss: 0.2658 - val_accuracy: 0.9060
# Epoch 13/20
# 56/56 - 1s - loss: 0.2914 - accuracy: 0.8955 - val_loss: 0.2635 - val_accuracy: 0.8971
# Epoch 14/20
# 56/56 - 1s - loss: 0.2896 - accuracy: 0.8961 - val_loss: 0.2643 - val_accuracy: 0.9038
# Epoch 15/20
# 56/56 - 1s - loss: 0.2864 - accuracy: 0.8952 - val_loss: 0.2629 - val_accuracy: 0.9038
# Epoch 16/20
# 56/56 - 1s - loss: 0.2848 - accuracy: 0.8975 - val_loss: 0.2611 - val_accuracy: 0.9038
# Epoch 17/20
# 56/56 - 0s - loss: 0.2862 - accuracy: 0.8952 - val_loss: 0.2553 - val_accuracy: 0.9105
# Epoch 18/20
# 56/56 - 1s - loss: 0.2836 - accuracy: 0.8961 - val_loss: 0.2585 - val_accuracy: 0.9038
# Epoch 19/20
# 56/56 - 0s - loss: 0.2807 - accuracy: 0.8980 - val_loss: 0.2523 - val_accuracy: 0.9083
# Epoch 20/20
# 56/56 - 1s - loss: 0.2825 - accuracy: 0.8955 - val_loss: 0.2642 - val_accuracy: 0.8993
# 14/14 [==============================] - 0s 742us/step - loss: 0.2642 - accuracy: 0.8993
# INFO:tensorflow:Assets written to: saved_models\Model 1\Run-7\assets
# --- Starting trial: run-8
# {'activation_function': 'sigmoid', 'hidden_layer_size': 128}
# Epoch 1/20
# 56/56 - 1s - loss: 0.6517 - accuracy: 0.6052 - val_loss: 0.5842 - val_accuracy: 0.6823
# Epoch 2/20
# 56/56 - 1s - loss: 0.4993 - accuracy: 0.8061 - val_loss: 0.4196 - val_accuracy: 0.8814
# Epoch 3/20
# 56/56 - 1s - loss: 0.3798 - accuracy: 0.8765 - val_loss: 0.3383 - val_accuracy: 0.8859
# Epoch 4/20
# 56/56 - 1s - loss: 0.3372 - accuracy: 0.8768 - val_loss: 0.3141 - val_accuracy: 0.8770
# Epoch 5/20
# 56/56 - 0s - loss: 0.3267 - accuracy: 0.8807 - val_loss: 0.3220 - val_accuracy: 0.8770
# Epoch 6/20
# 56/56 - 1s - loss: 0.3207 - accuracy: 0.8852 - val_loss: 0.2946 - val_accuracy: 0.8926
# Epoch 7/20
# 56/56 - 0s - loss: 0.3121 - accuracy: 0.8871 - val_loss: 0.2838 - val_accuracy: 0.8949
# Epoch 8/20
# 56/56 - 0s - loss: 0.3096 - accuracy: 0.8874 - val_loss: 0.2791 - val_accuracy: 0.8949
# Epoch 9/20
# 56/56 - 1s - loss: 0.3029 - accuracy: 0.8916 - val_loss: 0.2746 - val_accuracy: 0.8949
# Epoch 10/20
# 56/56 - 1s - loss: 0.3008 - accuracy: 0.8891 - val_loss: 0.2774 - val_accuracy: 0.8993
# Epoch 11/20
# 56/56 - 1s - loss: 0.3042 - accuracy: 0.8899 - val_loss: 0.2670 - val_accuracy: 0.9016
# Epoch 12/20
# 56/56 - 1s - loss: 0.2989 - accuracy: 0.8910 - val_loss: 0.2654 - val_accuracy: 0.9016
# Epoch 13/20
# 56/56 - 1s - loss: 0.2944 - accuracy: 0.8930 - val_loss: 0.2630 - val_accuracy: 0.9083
# Epoch 14/20
# 56/56 - 1s - loss: 0.2931 - accuracy: 0.8919 - val_loss: 0.2694 - val_accuracy: 0.9016
# Epoch 15/20
# 56/56 - 1s - loss: 0.2908 - accuracy: 0.8963 - val_loss: 0.2780 - val_accuracy: 0.8949
# 14/14 [==============================] - 0s 784us/step - loss: 0.2630 - accuracy: 0.9083
# INFO:tensorflow:Assets written to: saved_models\Model 1\Run-8\assets

# %%
# %load_ext tensorboard
# %tensorboard --logdir "Logs/Model 1/hparam_tuning"
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 10788), started 0:00:59 ago. (Use '!kill 10788' to kill it.)
#       <iframe id="tensorboard-frame-f5767f2170208bc4" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f5767f2170208bc4");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %load_ext tensorboard
# %tensorboard --logdir "Logs/Model 1/fit"
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 8776), started 0:01:04 ago. (Use '!kill 8776' to kill it.)
#       <iframe id="tensorboard-frame-f255ec3f5e22105e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f255ec3f5e22105e");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Test the model

# %%
# Loading a model to evaluate on the test set
model = tf.keras.models.load_model(r"saved_models\Model 1\Run-1")

# %%
test_pred = np.argmax(model.predict(test_inputs), axis=1)
test_accuracy = (test_targets == test_pred).sum() / test_targets.shape[0]

# %%
print('\nTest accuracy: {0:.2f}%'.format(test_accuracy * 100.))
# Out:
# Test accuracy: 91.29%
